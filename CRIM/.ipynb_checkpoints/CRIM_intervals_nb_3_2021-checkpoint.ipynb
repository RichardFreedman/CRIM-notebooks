# %% [markdown]
# ## Search with Options
#
# - Piece or Corpus
# - Actual or Incremental Durations
# - Chromatic or Diatonic
# - Exact or Close
# - Classify
#
# ***

# %%
from crim_intervals import *
import pandas as pd
import ast
import matplotlib
from itertools import tee, combinations
import numpy as np
from fractions import Fraction

# %% [markdown]
# ### Short Corpus

# %%
# work_list = ['CRIM_Mass_0002_1.mei',
#  'CRIM_Mass_0002_2.mei',
#  'CRIM_Mass_0002_3.mei',
#  'CRIM_Mass_0002_4.mei',
#  'CRIM_Mass_0002_5.mei',
# 'CRIM_Model_0001.mei']
git = 'https://raw.githubusercontent.com/RichardFreedman/CRIM_additional_works/main/'
work_list = [git + 'Gombert_Super_flumina.mei_msg.mei']
# work_list
corpus = CorpusBase(work_list)
for s in corpus.scores:
    print(s.metadata.title)
# Out:
# Requesting file from https://raw.githubusercontent.com/RichardFreedman/CRIM_additional_works/main/Gombert_Super_flumina.mei_msg.mei...
# Successfully imported.
# Super flumina babylonis

# %% [markdown]
# ## Load File and Correct the MEI Metadata

# %%
# work_list = [el.replace("CRIM_", "https://crimproject.org/mei/MEI_4.0/CRIM_") for el in work_list]
# corpus = CorpusBase(work_list)

# import xml.etree.ElementTree as ET
# import requests

# MEINSURI = 'http://www.music-encoding.org/ns/mei'
# MEINS = '{%s}' % MEINSURI

# for i, path in enumerate(work_list):
    
#     try:
#         if path[0] == '/':
#             mei_doc = ET.parse(path)
#         else:
#             mei_doc = ET.fromstring(requests.get(path).text)

#       # Find the title from the MEI file and update the Music21 Score metadata
#         title = mei_doc.find('mei:meiHead//mei:titleStmt/mei:title', namespaces={"mei": MEINSURI}).text
#         print(path, title)
#         corpus.scores[i].metadata.title = title
#     except:
#         continue

# for s in corpus.scores:
#     print(s.metadata.title)

# %% [markdown]
# ## Select Actual or Incremental Durations
#
# #### About Rhythmic Durations
#
# - For `find_close_matches` and `find_exact_matches`, rhythmic variation/duration is displayed, but **not** factored into the calculation of matching.
# - **Incremental Offset** calculates the intervals using a **fixed offset between notes**, no matter their actual duration.  Use this to ignore passing tones or other ornaments.  The offsets are expressed in multiples of the quarter note (Offset = 1 samples at quarter note; Offset = 2 at half note, etc). Set with `vectors = IntervalBase(corpus.note_list_incremental_offset(2))`

# %%
vectors = IntervalBase(corpus.note_list)
#vectors = IntervalBase(corpus.note_list_incremental_offset(2))

# %% [markdown]
# ***
#
# ## Select Generic or Semitone Scale:
#
# - **Length of the Soggetto**: `into_patterns([vectors.semitone_intervals], 5)`
#
# - The **number** in this command represents the **minimum number of vectors to find**. 5 vectors is 6 notes.

# %%
patterns = into_patterns([vectors.generic_intervals], 5)
#patterns = into_patterns([vectors.semitone_intervals], 4)

# %% [markdown]
# ***
#
# ## Select Exact Matches Here, or Close Below
# #### (Use comment feature to select screen preview or CSV output)
#
# - **Exact** is exact in *all* ways `find_exact_matches(patterns, 2)`
# - The **number** in this command represents the **minimum number of matching melodies needed before reporting**. This allows us to filter for common or uncommon soggetti.

# %%
exact_matches = find_exact_matches(patterns, 2)
output_exact = export_pandas(exact_matches)
pd.DataFrame(output_exact).head()
pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(output_exact)
# output_exact.head(50)
# df = output_exact
# output_exact["pattern_generating_match"] = output_exact["pattern_generating_match"].apply(tuple)

# results = pd.DataFrame(output_exact)
# results["pattern_generating_match"] = results["pattern_generating_match"].apply(tuple)
# results.head(10)
# export_to_csv(exact_matches)
# file_name = "work_list"+"exact_5.csv"
# output_exact.to_csv("Riquet_Kyrie.csv")
# Out:
# Finding exact matches...
# 108 melodic intervals had more than 2 exact matches.

# %%
df = output_exact
pd.set_option("display.max_rows", None, "display.max_columns", None)
# print(df)
# df.head()
# df.note_durations.astype("str")

# %%
df["note_durations"] = df["note_durations"].map(lambda x: pd.eval(x))
df["start_offset"] = df["start_offset"].map(lambda x: pd.eval(x))
df["end_offset"] = df["end_offset"].map(lambda x: pd.eval(x))
df = df.round(2)
df.to_csv("Gombert.csv")
# print(df.note_durations)
# Out:
# dtype('O')

# %% [markdown]
# ***
#
# ### Select Close Matches Here
# #### (Comment out the 'for item iteration' in order to skip screen preview)
#
# - **Close** matches allow for melodic variation (see more below). `find_close_matches(patterns, 2, 1)`
# - The **first number** in this command is the **minimum number of melodies** needed before reporting
# - The **second number** is **threshold of similarity** needed in order to find a match.
# - Lower number = very similar; higher number = less similar
#
# ##### More about Close Matches
# - The **threshold for close matches** is determined by the **second number** called in the method.
# - We select two patterns, then compare *each vector in each pattern successively*.
# - The *differences between each vector are summed*.
# - If that value is **below the threshold specified**, we consider the **two patterns closely matched**.
# - The format of the method call is  `find_close_matches(the array you get from into_patterns, minimum matches needed to be displayed, threshold for close match)`.

# %%
close_matches = find_close_matches(patterns, 4, 1)
#for item in close_matches:
   #item.print_close_matches()
    #return pd.DataFrame(close_matches)

output_close = export_pandas(close_matches)
output_close["pattern_generating_match"] = output_close["pattern_generating_match"].apply(tuple)

results = pd.DataFrame(output_close)
results["pattern_generating_match"] = results["pattern_generating_match"].apply(tuple)
results.head()

results.to_csv("Model_0001_Close_3_1")
# export_to_csv(close_matches)
# Out:
# Finding close matches...
# 201 melodic intervals had more than 4 exact or close matches.

# %% [markdown]
# ***
#
# ## Classify Patterns Here
# #### Note:  depends on choice of Close or Exact above!  Must choose appropriate one below!
# #### Enable "export_to_csv" line to allow this within Notebook (must answer "Y" and provide filename)
#
# #### note that the classifier can only find patterns with AT LEAST THREE entries!  2-voice fugas are invisible at the moment.  Could be added!

# %%
# THIS IS DEV COPY for use with CLOSE/EXACT Matches

import numpy as np

# Converts lists to tuples

def lists_to_tuples_a(el):
    if isinstance(el, list):
        return tuple(el)
    else:
        return el

# Filters for the length of the Presentation Type in the Classifier

def limit_offset_size(array, limit):
    under_limit = np.cumsum(array) <= limit
    return array[: sum(under_limit)]

# Gets the the list of offset differences for each group 

def get_offset_difference_list_a(group):
    # if we do sort values as part of the func call, then we don't need this first line
    group = group.sort_values("start_offset")
    group["next_offset"] = group.start_offset.shift(-1)
    offset_difference_list = (group.next_offset - group.start_offset).dropna().tolist()
    return offset_difference_list

# The classifications are done here
# be sure to have the offset difference limit set here and matched in gap check below  80 = ten bars

def classify_offsets_a(offset_difference_list):
    """
    Put logic for classifying an offset list here
    """
    # 
    offset_difference_list = limit_offset_size(offset_difference_list, 500)
    
    alt_list = offset_difference_list[::2]
    
    if len(set(offset_difference_list)) == 1 and len(offset_difference_list) > 1:
        return ("PEN", offset_difference_list)
    # elif (len(offset_difference_list) %2 != 0) and (len(set(alt_list)) == 1):
    elif (len(offset_difference_list) %2 != 0) and (len(set(alt_list)) == 1) and (len(offset_difference_list) >= 3):
        return ("ID", offset_difference_list)
    elif len(offset_difference_list) >= 1:
        return ("Fuga", offset_difference_list)
    else: 
        return ("Singleton", offset_difference_list)
    
# adds predicted type, offsets and entry numbers to the results

def predict_type_a(group):
    offset_differences = get_offset_difference_list_a(group)
    predicted_type, offsets = classify_offsets_a(offset_differences)

    group["predicted_type"] = [predicted_type for i in range(len(group))]
    group["offset_diffs"] = [offsets for i in range(len(group))]
    group["entry_number"] = [i + 1 for i in range(len(group))]

    return group

# %%
# lists for views.  These are used when calling the df below

simple_view = ["piece_title", "part", "pattern_generating_match", "pattern_matched", "start_offset"]

offset_details = ["start_measure", "start_beat", "end_offset", "note_durations", "prev_entry_off", "next_entry_off"]

drop_cols = ["pattern_matched", "part", "pattern_generating_match", "piece_title", "start_measure", "start_beat", "end_offset", "note_durations", "prev_entry_off", "next_entry_off"]

ready_classify = ["pattern_generating_match", "pattern_matched", "piece_title", "part", "start_measure", "start_beat", "start_offset", "sub_group_id", "is_first"]

# %%
# # df['note_durations'] = df.note_durations.apply(str)
# df['note_durations'] = df.note_durations.apply(ast.literal_eval)
# # df['note_durations'] = df['note_durations'].str()
df["sum_durs"] = df.note_durations.apply(sum)
# # df['note_durations'] = df.note_durations.apply(ast.literal_eval)
# # print(df)
# # df.dtypes

# try:
#     df['note_durations'] = df.note_durations.apply(ast.literal_eval)
# except:
#     pass
# df["sum_durs"] = df.note_durations.apply(sum)

# %%
df.applymap(lists_to_tuples_a)
# Out:
#     pattern_generating_match       pattern_matched              piece_title  \
# 0        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 1        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 2        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 3        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 4        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 5        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 6        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 7        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 8        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 9        (-2, -2, -2, 4, -2)   (-2, -2, -2, 4, -2)  Super flumina babylonis
# 10        (-2, -2, 4, -2, 2)    (-2, -2, 4, -2, 2)  Super flumina babylonis
# 11        (-2, -2, 4, -2, 2)    (-2, -2, 4, -2, 2)  Super flumina babylonis
# 12        (-2, -2, 4, -2, 2)    (-2, -2, 4, -2, 2)  Super flumina babylonis
# 13        (-2, -2, 4, -2, 2)    (-2, -2, 4, -2, 2)  Super flumina babylonis
# 14         (-2, 4, -2, 2, 2)     (-2, 4, -2, 2, 2)  Super flumina babylonis
# 15         (-2, 4, -2, 2, 2)     (-2, 4, -2, 2, 2)  Super flumina babylonis
# 16         (-2, 4, -2, 2, 2)     (-2, 4, -2, 2, 2)  Super flumina babylonis
# 17         (-2, 4, -2, 2, 2)     (-2, 4, -2, 2, 2)  Super flumina babylonis
# 18         (4, -2, 2, 2, -5)     (4, -2, 2, 2, -5)  Super flumina babylonis
# 19         (4, -2, 2, 2, -5)     (4, -2, 2, 2, -5)  Super flumina babylonis
# 20         (4, -2, 2, 2, -5)     (4, -2, 2, 2, -5)  Super flumina babylonis
# 21         (4, -2, 2, 2, -5)     (4, -2, 2, 2, -5)  Super flumina babylonis
# 22          (2, 2, 2, 3, -2)      (2, 2, 2, 3, -2)  Super flumina babylonis
# 23          (2, 2, 2, 3, -2)      (2, 2, 2, 3, -2)  Super flumina babylonis
# 24          (2, 2, 2, 3, -2)      (2, 2, 2, 3, -2)  Super flumina babylonis
# 25          (2, 2, 2, 3, -2)      (2, 2, 2, 3, -2)  Super flumina babylonis
# 26          (2, 2, 2, 3, -2)      (2, 2, 2, 3, -2)  Super flumina babylonis
# 27         (2, 2, 3, -2, -2)     (2, 2, 3, -2, -2)  Super flumina babylonis
# 28         (2, 2, 3, -2, -2)     (2, 2, 3, -2, -2)  Super flumina babylonis
# 29         (2, 2, 3, -2, -2)     (2, 2, 3, -2, -2)  Super flumina babylonis
# 30         (2, 2, 3, -2, -2)     (2, 2, 3, -2, -2)  Super flumina babylonis
# 31         (2, 2, 3, -2, -2)     (2, 2, 3, -2, -2)  Super flumina babylonis
# 32         (2, 2, 3, -2, -2)     (2, 2, 3, -2, -2)  Super flumina babylonis
# 33        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 34        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 35        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 36        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 37        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 38        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 39        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 40        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 41        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 42        (2, 3, -2, -2, -2)    (2, 3, -2, -2, -2)  Super flumina babylonis
# 43       (3, -2, -2, -2, -2)   (3, -2, -2, -2, -2)  Super flumina babylonis
# 44       (3, -2, -2, -2, -2)   (3, -2, -2, -2, -2)  Super flumina babylonis
# 45       (3, -2, -2, -2, -2)   (3, -2, -2, -2, -2)  Super flumina babylonis
# 46       (3, -2, -2, -2, -2)   (3, -2, -2, -2, -2)  Super flumina babylonis
# 47       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 48       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 49       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 50       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 51       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 52       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 53       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 54       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 55       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 56       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 57       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 58       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 59       (-2, -2, -2, -2, 2)   (-2, -2, -2, -2, 2)  Super flumina babylonis
# 60        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 61        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 62        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 63        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 64        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 65        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 66        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 67        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 68        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 69        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 70        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 71        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 72        (-2, -2, -2, 2, 2)    (-2, -2, -2, 2, 2)  Super flumina babylonis
# 73        (-2, -2, 2, 2, -2)    (-2, -2, 2, 2, -2)  Super flumina babylonis
# 74        (-2, -2, 2, 2, -2)    (-2, -2, 2, 2, -2)  Super flumina babylonis
# 75        (-2, -2, 2, 2, -2)    (-2, -2, 2, 2, -2)  Super flumina babylonis
# 76        (-2, -2, 2, 2, -2)    (-2, -2, 2, 2, -2)  Super flumina babylonis
# 77        (-2, -2, 2, 2, -2)    (-2, -2, 2, 2, -2)  Super flumina babylonis
# 78        (-2, -2, 2, 2, -2)    (-2, -2, 2, 2, -2)  Super flumina babylonis
# 79         (-2, 2, 2, -2, 2)     (-2, 2, 2, -2, 2)  Super flumina babylonis
# 80         (-2, 2, 2, -2, 2)     (-2, 2, 2, -2, 2)  Super flumina babylonis
# 81         (-2, 2, 2, -2, 2)     (-2, 2, 2, -2, 2)  Super flumina babylonis
# 82         (-2, 2, 2, -2, 2)     (-2, 2, 2, -2, 2)  Super flumina babylonis
# 83       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 84       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 85       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 86       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 87       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 88       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 89       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 90       (-2, -2, 3, -2, -2)   (-2, -2, 3, -2, -2)  Super flumina babylonis
# 91       (-2, 3, -2, -2, -2)   (-2, 3, -2, -2, -2)  Super flumina babylonis
# 92       (-2, 3, -2, -2, -2)   (-2, 3, -2, -2, -2)  Super flumina babylonis
# 93       (-2, 3, -2, -2, -2)   (-2, 3, -2, -2, -2)  Super flumina babylonis
# 94       (-2, 3, -2, -2, -2)   (-2, 3, -2, -2, -2)  Super flumina babylonis
# 95       (-2, 3, -2, -2, -2)   (-2, 3, -2, -2, -2)  Super flumina babylonis
# 96       (-2, 3, -2, -2, -2)   (-2, 3, -2, -2, -2)  Super flumina babylonis
# 97          (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 98          (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 99          (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 100         (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 101         (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 102         (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 103         (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 104         (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 105         (1, 1, 2, -3, 2)      (1, 1, 2, -3, 2)  Super flumina babylonis
# 106        (1, 2, -3, 2, -3)     (1, 2, -3, 2, -3)  Super flumina babylonis
# 107        (1, 2, -3, 2, -3)     (1, 2, -3, 2, -3)  Super flumina babylonis
# 108        (1, 2, -3, 2, -3)     (1, 2, -3, 2, -3)  Super flumina babylonis
# 109       (2, -3, 2, -2, -2)    (2, -3, 2, -2, -2)  Super flumina babylonis
# 110       (2, -3, 2, -2, -2)    (2, -3, 2, -2, -2)  Super flumina babylonis
# 111       (2, -3, 2, -2, -2)    (2, -3, 2, -2, -2)  Super flumina babylonis
# 112       (2, -3, 2, -2, -2)    (2, -3, 2, -2, -2)  Super flumina babylonis
# 113       (2, -3, 2, -2, -2)    (2, -3, 2, -2, -2)  Super flumina babylonis
# 114      (-3, 2, -2, -2, -2)   (-3, 2, -2, -2, -2)  Super flumina babylonis
# 115      (-3, 2, -2, -2, -2)   (-3, 2, -2, -2, -2)  Super flumina babylonis
# 116      (-3, 2, -2, -2, -2)   (-3, 2, -2, -2, -2)  Super flumina babylonis
# 117      (-3, 2, -2, -2, -2)   (-3, 2, -2, -2, -2)  Super flumina babylonis
# 118      (-3, 2, -2, -2, -2)   (-3, 2, -2, -2, -2)  Super flumina babylonis
# 119      (-3, 2, -2, -2, -2)   (-3, 2, -2, -2, -2)  Super flumina babylonis
# 120      (-3, 2, -2, -2, -2)   (-3, 2, -2, -2, -2)  Super flumina babylonis
# 121      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 122      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 123      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 124      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 125      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 126      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 127      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 128      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 129      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 130      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 131      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 132      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 133      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 134      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 135      (2, -2, -2, -2, -2)   (2, -2, -2, -2, -2)  Super flumina babylonis
# 136      (-2, -2, -2, -2, 4)   (-2, -2, -2, -2, 4)  Super flumina babylonis
# 137      (-2, -2, -2, -2, 4)   (-2, -2, -2, -2, 4)  Super flumina babylonis
# 138      (-2, -2, -2, -2, 4)   (-2, -2, -2, -2, 4)  Super flumina babylonis
# 139      (-2, -2, -2, -2, 4)   (-2, -2, -2, -2, 4)  Super flumina babylonis
# 140        (2, 2, -2, -2, 1)     (2, 2, -2, -2, 1)  Super flumina babylonis
# 141        (2, 2, -2, -2, 1)     (2, 2, -2, -2, 1)  Super flumina babylonis
# 142        (2, 2, -2, -2, 1)     (2, 2, -2, -2, 1)  Super flumina babylonis
# 143        (2, 2, -2, -2, 1)     (2, 2, -2, -2, 1)  Super flumina babylonis
# 144        (2, 2, -2, -2, 1)     (2, 2, -2, -2, 1)  Super flumina babylonis
# 145       (2, -2, -2, 1, -2)    (2, -2, -2, 1, -2)  Super flumina babylonis
# 146       (2, -2, -2, 1, -2)    (2, -2, -2, 1, -2)  Super flumina babylonis
# 147       (2, -2, -2, 1, -2)    (2, -2, -2, 1, -2)  Super flumina babylonis
# 148       (2, -2, -2, 1, -2)    (2, -2, -2, 1, -2)  Super flumina babylonis
# 149       (2, -2, -2, 1, -2)    (2, -2, -2, 1, -2)  Super flumina babylonis
# 150       (-2, -2, 1, -2, 2)    (-2, -2, 1, -2, 2)  Super flumina babylonis
# 151       (-2, -2, 1, -2, 2)    (-2, -2, 1, -2, 2)  Super flumina babylonis
# 152       (-2, -2, 1, -2, 2)    (-2, -2, 1, -2, 2)  Super flumina babylonis
# 153       (-2, -2, 1, -2, 2)    (-2, -2, 1, -2, 2)  Super flumina babylonis
# 154       (-2, -2, 1, -2, 2)    (-2, -2, 1, -2, 2)  Super flumina babylonis
# 155       (-2, -2, 1, -2, 2)    (-2, -2, 1, -2, 2)  Super flumina babylonis
# 156       (-2, -2, 1, -2, 2)    (-2, -2, 1, -2, 2)  Super flumina babylonis
# 157         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 158         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 159         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 160         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 161         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 162         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 163         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 164         (-2, 2, 2, 2, 1)      (-2, 2, 2, 2, 1)  Super flumina babylonis
# 165          (2, 2, 2, 1, 1)       (2, 2, 2, 1, 1)  Super flumina babylonis
# 166          (2, 2, 2, 1, 1)       (2, 2, 2, 1, 1)  Super flumina babylonis
# 167          (2, 2, 2, 1, 1)       (2, 2, 2, 1, 1)  Super flumina babylonis
# 168          (2, 2, 2, 1, 1)       (2, 2, 2, 1, 1)  Super flumina babylonis
# 169          (2, 2, 2, 1, 1)       (2, 2, 2, 1, 1)  Super flumina babylonis
# 170          (2, 2, 2, 1, 1)       (2, 2, 2, 1, 1)  Super flumina babylonis
# 171          (2, 2, 2, 1, 1)       (2, 2, 2, 1, 1)  Super flumina babylonis
# 172          (2, 2, 1, 1, 1)       (2, 2, 1, 1, 1)  Super flumina babylonis
# 173          (2, 2, 1, 1, 1)       (2, 2, 1, 1, 1)  Super flumina babylonis
# 174          (2, 2, 1, 1, 1)       (2, 2, 1, 1, 1)  Super flumina babylonis
# 175          (2, 2, 1, 1, 1)       (2, 2, 1, 1, 1)  Super flumina babylonis
# 176          (2, 2, 1, 1, 1)       (2, 2, 1, 1, 1)  Super flumina babylonis
# 177          (2, 2, 1, 1, 1)       (2, 2, 1, 1, 1)  Super flumina babylonis
# 178         (2, 1, 1, 1, -2)      (2, 1, 1, 1, -2)  Super flumina babylonis
# 179         (2, 1, 1, 1, -2)      (2, 1, 1, 1, -2)  Super flumina babylonis
# 180         (2, 1, 1, 1, -2)      (2, 1, 1, 1, -2)  Super flumina babylonis
# 181         (2, 1, 1, 1, -2)      (2, 1, 1, 1, -2)  Super flumina babylonis
# 182         (2, 1, 1, 1, -2)      (2, 1, 1, 1, -2)  Super flumina babylonis
# 183         (2, 1, 1, 1, -2)      (2, 1, 1, 1, -2)  Super flumina babylonis
# 184        (1, 1, 1, -2, -3)     (1, 1, 1, -2, -3)  Super flumina babylonis
# 185        (1, 1, 1, -2, -3)     (1, 1, 1, -2, -3)  Super flumina babylonis
# 186        (1, 1, 1, -2, -3)     (1, 1, 1, -2, -3)  Super flumina babylonis
# 187        (1, 1, 1, -2, -3)     (1, 1, 1, -2, -3)  Super flumina babylonis
# 188        (1, 1, 1, -2, -3)     (1, 1, 1, -2, -3)  Super flumina babylonis
# 189        (1, 1, -2, -3, 2)     (1, 1, -2, -3, 2)  Super flumina babylonis
# 190        (1, 1, -2, -3, 2)     (1, 1, -2, -3, 2)  Super flumina babylonis
# 191        (1, 1, -2, -3, 2)     (1, 1, -2, -3, 2)  Super flumina babylonis
# 192        (1, 1, -2, -3, 2)     (1, 1, -2, -3, 2)  Super flumina babylonis
# 193        (1, 1, -2, -3, 2)     (1, 1, -2, -3, 2)  Super flumina babylonis
# 194        (1, 1, -2, -3, 2)     (1, 1, -2, -3, 2)  Super flumina babylonis
# 195        (1, 1, -2, -3, 2)     (1, 1, -2, -3, 2)  Super flumina babylonis
# 196       (1, -2, -3, 2, -2)    (1, -2, -3, 2, -2)  Super flumina babylonis
# 197       (1, -2, -3, 2, -2)    (1, -2, -3, 2, -2)  Super flumina babylonis
# 198       (1, -2, -3, 2, -2)    (1, -2, -3, 2, -2)  Super flumina babylonis
# 199       (1, -2, -3, 2, -2)    (1, -2, -3, 2, -2)  Super flumina babylonis
# 200      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 201      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 202      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 203      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 204      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 205      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 206      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 207      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 208      (-2, -3, 2, -2, -2)   (-2, -3, 2, -2, -2)  Super flumina babylonis
# 209       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 210       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 211       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 212       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 213       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 214       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 215       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 216       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 217       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 218       (2, -2, -2, -2, 2)    (2, -2, -2, -2, 2)  Super flumina babylonis
# 219      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 220      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 221      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 222      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 223      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 224      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 225      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 226      (-2, -2, -2, 2, -2)   (-2, -2, -2, 2, -2)  Super flumina babylonis
# 227      (-2, -2, 2, -2, -2)   (-2, -2, 2, -2, -2)  Super flumina babylonis
# 228      (-2, -2, 2, -2, -2)   (-2, -2, 2, -2, -2)  Super flumina babylonis
# 229      (-2, -2, 2, -2, -2)   (-2, -2, 2, -2, -2)  Super flumina babylonis
# 230      (-2, -2, 2, -2, -2)   (-2, -2, 2, -2, -2)  Super flumina babylonis
# 231      (-2, -2, 2, -2, -2)   (-2, -2, 2, -2, -2)  Super flumina babylonis
# 232      (-2, -2, 2, -2, -2)   (-2, -2, 2, -2, -2)  Super flumina babylonis
# 233      (-2, -2, 2, -2, -2)   (-2, -2, 2, -2, -2)  Super flumina babylonis
# 234      (-2, 2, -2, -2, -2)   (-2, 2, -2, -2, -2)  Super flumina babylonis
# 235      (-2, 2, -2, -2, -2)   (-2, 2, -2, -2, -2)  Super flumina babylonis
# 236      (-2, 2, -2, -2, -2)   (-2, 2, -2, -2, -2)  Super flumina babylonis
# 237      (-2, 2, -2, -2, -2)   (-2, 2, -2, -2, -2)  Super flumina babylonis
# 238      (-2, 2, -2, -2, -2)   (-2, 2, -2, -2, -2)  Super flumina babylonis
# 239      (-2, 2, -2, -2, -2)   (-2, 2, -2, -2, -2)  Super flumina babylonis
# 240      (-2, 2, -2, -2, -2)   (-2, 2, -2, -2, -2)  Super flumina babylonis
# 241      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 242      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 243      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 244      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 245      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 246      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 247      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 248      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 249      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 250      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 251      (-2, 4, -2, -2, -2)   (-2, 4, -2, -2, -2)  Super flumina babylonis
# 252      (4, -2, -2, -2, -2)   (4, -2, -2, -2, -2)  Super flumina babylonis
# 253      (4, -2, -2, -2, -2)   (4, -2, -2, -2, -2)  Super flumina babylonis
# 254      (4, -2, -2, -2, -2)   (4, -2, -2, -2, -2)  Super flumina babylonis
# 255      (4, -2, -2, -2, -2)   (4, -2, -2, -2, -2)  Super flumina babylonis
# 256      (4, -2, -2, -2, -2)   (4, -2, -2, -2, -2)  Super flumina babylonis
# 257      (4, -2, -2, -2, -2)   (4, -2, -2, -2, -2)  Super flumina babylonis
# 258      (4, -2, -2, -2, -2)   (4, -2, -2, -2, -2)  Super flumina babylonis
# 259        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 260        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 261        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 262        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 263        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 264        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 265        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 266        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 267        (-2, -2, 2, 2, 2)     (-2, -2, 2, 2, 2)  Super flumina babylonis
# 268        (-2, 2, 2, 2, -3)     (-2, 2, 2, 2, -3)  Super flumina babylonis
# 269        (-2, 2, 2, 2, -3)     (-2, 2, 2, 2, -3)  Super flumina babylonis
# 270        (-2, 2, 2, 2, -3)     (-2, 2, 2, 2, -3)  Super flumina babylonis
# 271        (-2, 2, 2, 2, -3)     (-2, 2, 2, 2, -3)  Super flumina babylonis
# 272         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 273         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 274         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 275         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 276         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 277         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 278         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 279         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 280         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 281         (2, 2, 2, -3, 2)      (2, 2, 2, -3, 2)  Super flumina babylonis
# 282         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 283         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 284         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 285         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 286         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 287         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 288         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 289         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 290         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 291         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 292         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 293         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 294         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 295         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 296         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 297         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 298         (2, 2, -3, 2, 2)      (2, 2, -3, 2, 2)  Super flumina babylonis
# 299        (2, -3, 2, 2, -2)     (2, -3, 2, 2, -2)  Super flumina babylonis
# 300        (2, -3, 2, 2, -2)     (2, -3, 2, 2, -2)  Super flumina babylonis
# 301        (2, -3, 2, 2, -2)     (2, -3, 2, 2, -2)  Super flumina babylonis
# 302        (2, -3, 2, 2, -2)     (2, -3, 2, 2, -2)  Super flumina babylonis
# 303       (-3, 2, 2, -2, -2)    (-3, 2, 2, -2, -2)  Super flumina babylonis
# 304       (-3, 2, 2, -2, -2)    (-3, 2, 2, -2, -2)  Super flumina babylonis
# 305       (-3, 2, 2, -2, -2)    (-3, 2, 2, -2, -2)  Super flumina babylonis
# 306       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 307       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 308       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 309       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 310       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 311       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 312       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 313       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 314       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 315       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 316       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 317       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 318       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 319       (2, 2, -2, -2, -2)    (2, 2, -2, -2, -2)  Super flumina babylonis
# 320         (2, 1, 2, -3, 2)      (2, 1, 2, -3, 2)  Super flumina babylonis
# 321         (2, 1, 2, -3, 2)      (2, 1, 2, -3, 2)  Super flumina babylonis
# 322         (2, 1, 2, -3, 2)      (2, 1, 2, -3, 2)  Super flumina babylonis
# 323         (1, 2, -3, 2, 2)      (1, 2, -3, 2, 2)  Super flumina babylonis
# 324         (1, 2, -3, 2, 2)      (1, 2, -3, 2, 2)  Super flumina babylonis
# 325         (1, 2, -3, 2, 2)      (1, 2, -3, 2, 2)  Super flumina babylonis
# 326         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 327         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 328         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 329         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 330         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 331         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 332         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 333         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 334         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 335         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 336         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 337         (2, -3, 2, 2, 2)      (2, -3, 2, 2, 2)  Super flumina babylonis
# 338        (-3, 2, 2, 2, -3)     (-3, 2, 2, 2, -3)  Super flumina babylonis
# 339        (-3, 2, 2, 2, -3)     (-3, 2, 2, 2, -3)  Super flumina babylonis
# 340        (-3, 2, 2, 2, -3)     (-3, 2, 2, 2, -3)  Super flumina babylonis
# 341        (-3, 2, 2, 2, -3)     (-3, 2, 2, 2, -3)  Super flumina babylonis
# 342        (-3, 2, 2, 2, -3)     (-3, 2, 2, 2, -3)  Super flumina babylonis
# 343        (-3, 2, 2, 2, -3)     (-3, 2, 2, 2, -3)  Super flumina babylonis
# 344         (2, 2, 2, -3, 5)      (2, 2, 2, -3, 5)  Super flumina babylonis
# 345         (2, 2, 2, -3, 5)      (2, 2, 2, -3, 5)  Super flumina babylonis
# 346         (2, 2, 2, -3, 5)      (2, 2, 2, -3, 5)  Super flumina babylonis
# 347         (2, 2, 2, -3, 5)      (2, 2, 2, -3, 5)  Super flumina babylonis
# 348         (2, 2, 2, -3, 5)      (2, 2, 2, -3, 5)  Super flumina babylonis
# 349         (2, 2, 2, -3, 5)      (2, 2, 2, -3, 5)  Super flumina babylonis
# 350         (2, 2, 2, -3, 5)      (2, 2, 2, -3, 5)  Super flumina babylonis
# 351        (2, 2, -3, 5, -2)     (2, 2, -3, 5, -2)  Super flumina babylonis
# 352        (2, 2, -3, 5, -2)     (2, 2, -3, 5, -2)  Super flumina babylonis
# 353        (2, 2, -3, 5, -2)     (2, 2, -3, 5, -2)  Super flumina babylonis
# 354        (2, 2, -3, 5, -2)     (2, 2, -3, 5, -2)  Super flumina babylonis
# 355        (2, 2, -3, 5, -2)     (2, 2, -3, 5, -2)  Super flumina babylonis
# 356        (2, 2, -3, 5, -2)     (2, 2, -3, 5, -2)  Super flumina babylonis
# 357        (2, 2, -3, 5, -2)     (2, 2, -3, 5, -2)  Super flumina babylonis
# 358       (2, -3, 5, -2, -2)    (2, -3, 5, -2, -2)  Super flumina babylonis
# 359       (2, -3, 5, -2, -2)    (2, -3, 5, -2, -2)  Super flumina babylonis
# 360       (2, -3, 5, -2, -2)    (2, -3, 5, -2, -2)  Super flumina babylonis
# 361       (2, -3, 5, -2, -2)    (2, -3, 5, -2, -2)  Super flumina babylonis
# 362       (2, -3, 5, -2, -2)    (2, -3, 5, -2, -2)  Super flumina babylonis
# 363      (-3, 5, -2, -2, -2)   (-3, 5, -2, -2, -2)  Super flumina babylonis
# 364      (-3, 5, -2, -2, -2)   (-3, 5, -2, -2, -2)  Super flumina babylonis
# 365      (-3, 5, -2, -2, -2)   (-3, 5, -2, -2, -2)  Super flumina babylonis
# 366     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 367     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 368     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 369     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 370     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 371     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 372     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 373     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 374     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 375     (-2, -2, -2, -2, -2)  (-2, -2, -2, -2, -2)  Super flumina babylonis
# 376        (-2, 2, 2, 2, -2)     (-2, 2, 2, 2, -2)  Super flumina babylonis
# 377        (-2, 2, 2, 2, -2)     (-2, 2, 2, 2, -2)  Super flumina babylonis
# 378        (-2, 2, 2, 2, -2)     (-2, 2, 2, 2, -2)  Super flumina babylonis
# 379        (-2, 2, 2, 2, -2)     (-2, 2, 2, 2, -2)  Super flumina babylonis
# 380        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 381        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 382        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 383        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 384        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 385        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 386        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 387        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 388        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 389        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 390        (2, 2, 2, -2, -2)     (2, 2, 2, -2, -2)  Super flumina babylonis
# 391     (-2, -2, -2, -2, -3)  (-2, -2, -2, -2, -3)  Super flumina babylonis
# 392     (-2, -2, -2, -2, -3)  (-2, -2, -2, -2, -3)  Super flumina babylonis
# 393     (-2, -2, -2, -2, -3)  (-2, -2, -2, -2, -3)  Super flumina babylonis
# 394      (-2, -2, -2, 3, -2)   (-2, -2, -2, 3, -2)  Super flumina babylonis
# 395      (-2, -2, -2, 3, -2)   (-2, -2, -2, 3, -2)  Super flumina babylonis
# 396      (-2, -2, -2, 3, -2)   (-2, -2, -2, 3, -2)  Super flumina babylonis
# 397      (-2, -2, -2, 3, -2)   (-2, -2, -2, 3, -2)  Super flumina babylonis
# 398      (-2, -2, -2, 3, -2)   (-2, -2, -2, 3, -2)  Super flumina babylonis
# 399      (-2, -2, -2, 3, -2)   (-2, -2, -2, 3, -2)  Super flumina babylonis
# 400       (3, -2, -2, 2, -2)    (3, -2, -2, 2, -2)  Super flumina babylonis
# 401       (3, -2, -2, 2, -2)    (3, -2, -2, 2, -2)  Super flumina babylonis
# 402       (3, -2, -2, 2, -2)    (3, -2, -2, 2, -2)  Super flumina babylonis
# 403        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 404        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 405        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 406        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 407        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 408        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 409        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 410        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 411        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 412        (-3, 2, 2, 2, -2)     (-3, 2, 2, 2, -2)  Super flumina babylonis
# 413         (2, 2, 2, -2, 2)      (2, 2, 2, -2, 2)  Super flumina babylonis
# 414         (2, 2, 2, -2, 2)      (2, 2, 2, -2, 2)  Super flumina babylonis
# 415         (2, 2, 2, -2, 2)      (2, 2, 2, -2, 2)  Super flumina babylonis
# 416         (2, 2, 2, -2, 2)      (2, 2, 2, -2, 2)  Super flumina babylonis
# 417        (2, -2, 2, 2, -2)     (2, -2, 2, 2, -2)  Super flumina babylonis
# 418        (2, -2, 2, 2, -2)     (2, -2, 2, 2, -2)  Super flumina babylonis
# 419        (2, -2, 2, 2, -2)     (2, -2, 2, 2, -2)  Super flumina babylonis
# 420       (-2, 2, 2, -2, -2)    (-2, 2, 2, -2, -2)  Super flumina babylonis
# 421       (-2, 2, 2, -2, -2)    (-2, 2, 2, -2, -2)  Super flumina babylonis
# 422       (-2, 2, 2, -2, -2)    (-2, 2, 2, -2, -2)  Super flumina babylonis
# 423       (-2, 2, 2, -2, -2)    (-2, 2, 2, -2, -2)  Super flumina babylonis
# 424       (-2, 2, 2, -2, -2)    (-2, 2, 2, -2, -2)  Super flumina babylonis
# 425       (-2, 2, 2, -2, -2)    (-2, 2, 2, -2, -2)  Super flumina babylonis
# 426         (2, 3, -3, 2, 2)      (2, 3, -3, 2, 2)  Super flumina babylonis
# 427         (2, 3, -3, 2, 2)      (2, 3, -3, 2, 2)  Super flumina babylonis
# 428         (2, 3, -3, 2, 2)      (2, 3, -3, 2, 2)  Super flumina babylonis
# 429        (2, -3, 2, 2, -3)     (2, -3, 2, 2, -3)  Super flumina babylonis
# 430        (2, -3, 2, 2, -3)     (2, -3, 2, 2, -3)  Super flumina babylonis
# 431        (2, -3, 2, 2, -3)     (2, -3, 2, 2, -3)  Super flumina babylonis
# 432        (-3, 2, 2, -3, 2)     (-3, 2, 2, -3, 2)  Super flumina babylonis
# 433        (-3, 2, 2, -3, 2)     (-3, 2, 2, -3, 2)  Super flumina babylonis
# 434        (-3, 2, 2, -3, 2)     (-3, 2, 2, -3, 2)  Super flumina babylonis
# 435        (-3, 2, 2, -3, 2)     (-3, 2, 2, -3, 2)  Super flumina babylonis
# 436        (2, 2, -3, 2, -2)     (2, 2, -3, 2, -2)  Super flumina babylonis
# 437        (2, 2, -3, 2, -2)     (2, 2, -3, 2, -2)  Super flumina babylonis
# 438        (2, 2, -3, 2, -2)     (2, 2, -3, 2, -2)  Super flumina babylonis
# 439        (2, 2, -3, 2, -2)     (2, 2, -3, 2, -2)  Super flumina babylonis
# 440        (2, 2, -3, 2, -2)     (2, 2, -3, 2, -2)  Super flumina babylonis
# 441        (2, 2, -3, 2, -2)     (2, 2, -3, 2, -2)  Super flumina babylonis
# 442       (-3, 2, -2, -2, 2)    (-3, 2, -2, -2, 2)  Super flumina babylonis
# 443       (-3, 2, -2, -2, 2)    (-3, 2, -2, -2, 2)  Super flumina babylonis
# 444       (-3, 2, -2, -2, 2)    (-3, 2, -2, -2, 2)  Super flumina babylonis
# 445       (-3, 2, -2, -2, 2)    (-3, 2, -2, -2, 2)  Super flumina babylonis
# 446         (1, 2, 2, -3, 2)      (1, 2, 2, -3, 2)  Super flumina babylonis
# 447         (1, 2, 2, -3, 2)      (1, 2, 2, -3, 2)  Super flumina babylonis
# 448         (1, 2, 2, -3, 2)      (1, 2, 2, -3, 2)  Super flumina babylonis
# 449         (1, 2, 2, -3, 2)      (1, 2, 2, -3, 2)  Super flumina babylonis
# 450         (1, 2, 2, -3, 2)      (1, 2, 2, -3, 2)  Super flumina babylonis
# 451       (3, -2, -2, -2, 1)    (3, -2, -2, -2, 1)  Super flumina babylonis
# 452       (3, -2, -2, -2, 1)    (3, -2, -2, -2, 1)  Super flumina babylonis
# 453       (3, -2, -2, -2, 1)    (3, -2, -2, -2, 1)  Super flumina babylonis
# 454       (3, -2, -2, -2, 1)    (3, -2, -2, -2, 1)  Super flumina babylonis
# 455         (-3, 2, 2, 2, 2)      (-3, 2, 2, 2, 2)  Super flumina babylonis
# 456         (-3, 2, 2, 2, 2)      (-3, 2, 2, 2, 2)  Super flumina babylonis
# 457         (-3, 2, 2, 2, 2)      (-3, 2, 2, 2, 2)  Super flumina babylonis
# 458         (-3, 2, 2, 2, 2)      (-3, 2, 2, 2, 2)  Super flumina babylonis
# 459         (-3, 2, 2, 2, 2)      (-3, 2, 2, 2, 2)  Super flumina babylonis
# 460        (2, 2, 1, -2, -2)     (2, 2, 1, -2, -2)  Super flumina babylonis
# 461        (2, 2, 1, -2, -2)     (2, 2, 1, -2, -2)  Super flumina babylonis
# 462        (2, 2, 1, -2, -2)     (2, 2, 1, -2, -2)  Super flumina babylonis
# 463      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 464      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 465      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 466      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 467      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 468      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 469      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 470      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 471      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 472      (-2, -2, 4, -2, -2)   (-2, -2, 4, -2, -2)  Super flumina babylonis
# 473       (-2, 4, -2, -2, 2)    (-2, 4, -2, -2, 2)  Super flumina babylonis
# 474       (-2, 4, -2, -2, 2)    (-2, 4, -2, -2, 2)  Super flumina babylonis
# 475       (-2, 4, -2, -2, 2)    (-2, 4, -2, -2, 2)  Super flumina babylonis
# 476      (-2, -2, -2, -3, 2)   (-2, -2, -2, -3, 2)  Super flumina babylonis
# 477      (-2, -2, -2, -3, 2)   (-2, -2, -2, -3, 2)  Super flumina babylonis
# 478      (-2, -2, -2, -3, 2)   (-2, -2, -2, -3, 2)  Super flumina babylonis
# 479      (-2, -2, -2, -3, 2)   (-2, -2, -2, -3, 2)  Super flumina babylonis
# 480      (-2, -2, -2, -3, 2)   (-2, -2, -2, -3, 2)  Super flumina babylonis
# 481       (-2, -2, -3, 2, 2)    (-2, -2, -3, 2, 2)  Super flumina babylonis
# 482       (-2, -2, -3, 2, 2)    (-2, -2, -3, 2, 2)  Super flumina babylonis
# 483       (-2, -2, -3, 2, 2)    (-2, -2, -3, 2, 2)  Super flumina babylonis
# 484       (-2, -2, -3, 2, 2)    (-2, -2, -3, 2, 2)  Super flumina babylonis
# 485       (-2, -2, -3, 2, 2)    (-2, -2, -3, 2, 2)  Super flumina babylonis
# 486        (-2, -3, 2, 2, 2)     (-2, -3, 2, 2, 2)  Super flumina babylonis
# 487        (-2, -3, 2, 2, 2)     (-2, -3, 2, 2, 2)  Super flumina babylonis
# 488        (-2, -3, 2, 2, 2)     (-2, -3, 2, 2, 2)  Super flumina babylonis
# 489        (-2, -3, 2, 2, 2)     (-2, -3, 2, 2, 2)  Super flumina babylonis
# 490       (2, -2, 4, -2, -2)    (2, -2, 4, -2, -2)  Super flumina babylonis
# 491       (2, -2, 4, -2, -2)    (2, -2, 4, -2, -2)  Super flumina babylonis
# 492       (2, -2, 4, -2, -2)    (2, -2, 4, -2, -2)  Super flumina babylonis
# 493       (2, -2, 4, -2, -2)    (2, -2, 4, -2, -2)  Super flumina babylonis
# 494      (-2, -2, 3, -2, -3)   (-2, -2, 3, -2, -3)  Super flumina babylonis
# 495      (-2, -2, 3, -2, -3)   (-2, -2, 3, -2, -3)  Super flumina babylonis
# 496      (-2, -2, 3, -2, -3)   (-2, -2, 3, -2, -3)  Super flumina babylonis
# 497       (-2, -3, 2, 2, -2)    (-2, -3, 2, 2, -2)  Super flumina babylonis
# 498       (-2, -3, 2, 2, -2)    (-2, -3, 2, 2, -2)  Super flumina babylonis
# 499       (-2, -3, 2, 2, -2)    (-2, -3, 2, 2, -2)  Super flumina babylonis
# 500        (2, 2, -2, 1, -2)     (2, 2, -2, 1, -2)  Super flumina babylonis
# 501        (2, 2, -2, 1, -2)     (2, 2, -2, 1, -2)  Super flumina babylonis
# 502        (2, 2, -2, 1, -2)     (2, 2, -2, 1, -2)  Super flumina babylonis
# 503        (2, 2, -2, 1, -2)     (2, 2, -2, 1, -2)  Super flumina babylonis
# 504       (-2, 4, -2, 2, -4)    (-2, 4, -2, 2, -4)  Super flumina babylonis
# 505       (-2, 4, -2, 2, -4)    (-2, 4, -2, 2, -4)  Super flumina babylonis
# 506       (-2, 4, -2, 2, -4)    (-2, 4, -2, 2, -4)  Super flumina babylonis
# 507        (4, -2, 2, -4, 2)     (4, -2, 2, -4, 2)  Super flumina babylonis
# 508        (4, -2, 2, -4, 2)     (4, -2, 2, -4, 2)  Super flumina babylonis
# 509        (4, -2, 2, -4, 2)     (4, -2, 2, -4, 2)  Super flumina babylonis
# 510         (2, -4, 2, 2, 2)      (2, -4, 2, 2, 2)  Super flumina babylonis
# 511         (2, -4, 2, 2, 2)      (2, -4, 2, 2, 2)  Super flumina babylonis
# 512         (2, -4, 2, 2, 2)      (2, -4, 2, 2, 2)  Super flumina babylonis
# 513         (2, -4, 2, 2, 2)      (2, -4, 2, 2, 2)  Super flumina babylonis
# 514         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 515         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 516         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 517         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 518         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 519         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 520         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 521         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 522         (2, 2, 2, 2, -2)      (2, 2, 2, 2, -2)  Super flumina babylonis
# 523       (-2, 1, -2, 2, -4)    (-2, 1, -2, 2, -4)  Super flumina babylonis
# 524       (-2, 1, -2, 2, -4)    (-2, 1, -2, 2, -4)  Super flumina babylonis
# 525       (-2, 1, -2, 2, -4)    (-2, 1, -2, 2, -4)  Super flumina babylonis
# 526        (1, -2, 2, -4, 2)     (1, -2, 2, -4, 2)  Super flumina babylonis
# 527        (1, -2, 2, -4, 2)     (1, -2, 2, -4, 2)  Super flumina babylonis
# 528        (1, -2, 2, -4, 2)     (1, -2, 2, -4, 2)  Super flumina babylonis
# 529       (-2, 2, -4, 2, -2)    (-2, 2, -4, 2, -2)  Super flumina babylonis
# 530       (-2, 2, -4, 2, -2)    (-2, 2, -4, 2, -2)  Super flumina babylonis
# 531       (-2, 2, -4, 2, -2)    (-2, 2, -4, 2, -2)  Super flumina babylonis
# 532       (4, -2, -2, -2, 2)    (4, -2, -2, -2, 2)  Super flumina babylonis
# 533       (4, -2, -2, -2, 2)    (4, -2, -2, -2, 2)  Super flumina babylonis
# 534       (4, -2, -2, -2, 2)    (4, -2, -2, -2, 2)  Super flumina babylonis
# 535       (4, -2, -2, -2, 2)    (4, -2, -2, -2, 2)  Super flumina babylonis
# 536       (4, -2, -2, -2, 2)    (4, -2, -2, -2, 2)  Super flumina babylonis
# 537       (4, -2, -2, -2, 2)    (4, -2, -2, -2, 2)  Super flumina babylonis
# 538         (-2, 2, 2, 2, 2)      (-2, 2, 2, 2, 2)  Super flumina babylonis
# 539         (-2, 2, 2, 2, 2)      (-2, 2, 2, 2, 2)  Super flumina babylonis
# 540         (-2, 2, 2, 2, 2)      (-2, 2, 2, 2, 2)  Super flumina babylonis
# 541         (-2, 2, 2, 2, 2)      (-2, 2, 2, 2, 2)  Super flumina babylonis
# 542          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 543          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 544          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 545          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 546          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 547          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 548          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 549          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 550          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 551          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 552          (2, 2, 2, 2, 2)       (2, 2, 2, 2, 2)  Super flumina babylonis
# 553        (2, -2, -2, 2, 2)     (2, -2, -2, 2, 2)  Super flumina babylonis
# 554        (2, -2, -2, 2, 2)     (2, -2, -2, 2, 2)  Super flumina babylonis
# 555        (2, -2, -2, 2, 2)     (2, -2, -2, 2, 2)  Super flumina babylonis
# 556        (2, -2, -2, 2, 2)     (2, -2, -2, 2, 2)  Super flumina babylonis
# 557         (1, -2, 2, 2, 2)      (1, -2, 2, 2, 2)  Super flumina babylonis
# 558         (1, -2, 2, 2, 2)      (1, -2, 2, 2, 2)  Super flumina babylonis
# 559         (1, -2, 2, 2, 2)      (1, -2, 2, 2, 2)  Super flumina babylonis
# 560        (-2, 1, -2, 2, 2)     (-2, 1, -2, 2, 2)  Super flumina babylonis
# 561        (-2, 1, -2, 2, 2)     (-2, 1, -2, 2, 2)  Super flumina babylonis
# 562        (-2, 1, -2, 2, 2)     (-2, 1, -2, 2, 2)  Super flumina babylonis
# 563        (2, 2, 2, -2, -3)     (2, 2, 2, -2, -3)  Super flumina babylonis
# 564        (2, 2, 2, -2, -3)     (2, 2, 2, -2, -3)  Super flumina babylonis
# 565        (2, 2, 2, -2, -3)     (2, 2, 2, -2, -3)  Super flumina babylonis
# 566        (2, 2, 2, -2, -3)     (2, 2, 2, -2, -3)  Super flumina babylonis
# 567        (2, 2, 2, -2, -3)     (2, 2, 2, -2, -3)  Super flumina babylonis
# 568        (2, 2, -2, 2, -2)     (2, 2, -2, 2, -2)  Super flumina babylonis
# 569        (2, 2, -2, 2, -2)     (2, 2, -2, 2, -2)  Super flumina babylonis
# 570        (2, 2, -2, 2, -2)     (2, 2, -2, 2, -2)  Super flumina babylonis
# 571       (2, -2, 2, -2, -2)    (2, -2, 2, -2, -2)  Super flumina babylonis
# 572       (2, -2, 2, -2, -2)    (2, -2, 2, -2, -2)  Super flumina babylonis
# 573       (2, -2, 2, -2, -2)    (2, -2, 2, -2, -2)  Super flumina babylonis
# 574        (1, 1, 3, -2, -3)     (1, 1, 3, -2, -3)  Super flumina babylonis
# 575        (1, 1, 3, -2, -3)     (1, 1, 3, -2, -3)  Super flumina babylonis
# 576        (1, 1, 3, -2, -3)     (1, 1, 3, -2, -3)  Super flumina babylonis
# 577        (1, 1, 3, -2, -3)     (1, 1, 3, -2, -3)  Super flumina babylonis
# 578        (1, 3, -2, -3, 2)     (1, 3, -2, -3, 2)  Super flumina babylonis
# 579        (1, 3, -2, -3, 2)     (1, 3, -2, -3, 2)  Super flumina babylonis
# 580        (1, 3, -2, -3, 2)     (1, 3, -2, -3, 2)  Super flumina babylonis
# 581        (1, 3, -2, -3, 2)     (1, 3, -2, -3, 2)  Super flumina babylonis
# 582       (3, -2, -3, 2, -2)    (3, -2, -3, 2, -2)  Super flumina babylonis
# 583       (3, -2, -3, 2, -2)    (3, -2, -3, 2, -2)  Super flumina babylonis
# 584       (3, -2, -3, 2, -2)    (3, -2, -3, 2, -2)  Super flumina babylonis
# 585       (3, -2, -3, 2, -2)    (3, -2, -3, 2, -2)  Super flumina babylonis
# 586       (3, -2, -3, 2, -2)    (3, -2, -3, 2, -2)  Super flumina babylonis
# 587       (2, -2, -2, 3, -2)    (2, -2, -2, 3, -2)  Super flumina babylonis
# 588       (2, -2, -2, 3, -2)    (2, -2, -2, 3, -2)  Super flumina babylonis
# 589       (2, -2, -2, 3, -2)    (2, -2, -2, 3, -2)  Super flumina babylonis
# 590      (-2, -2, -2, 1, -2)   (-2, -2, -2, 1, -2)  Super flumina babylonis
# 591      (-2, -2, -2, 1, -2)   (-2, -2, -2, 1, -2)  Super flumina babylonis
# 592      (-2, -2, -2, 1, -2)   (-2, -2, -2, 1, -2)  Super flumina babylonis
# 593      (-3, 4, -2, -2, -2)   (-3, 4, -2, -2, -2)  Super flumina babylonis
# 594      (-3, 4, -2, -2, -2)   (-3, 4, -2, -2, -2)  Super flumina babylonis
# 595      (-3, 4, -2, -2, -2)   (-3, 4, -2, -2, -2)  Super flumina babylonis
# 596      (1, -2, -2, -2, -2)   (1, -2, -2, -2, -2)  Super flumina babylonis
# 597      (1, -2, -2, -2, -2)   (1, -2, -2, -2, -2)  Super flumina babylonis
# 598      (1, -2, -2, -2, -2)   (1, -2, -2, -2, -2)  Super flumina babylonis
# 599       (-2, -2, 3, -2, 4)    (-2, -2, 3, -2, 4)  Super flumina babylonis
# 600       (-2, -2, 3, -2, 4)    (-2, -2, 3, -2, 4)  Super flumina babylonis
# 601       (-2, -2, 3, -2, 4)    (-2, -2, 3, -2, 4)  Super flumina babylonis
# 602       (-2, 3, -2, 4, -2)    (-2, 3, -2, 4, -2)  Super flumina babylonis
# 603       (-2, 3, -2, 4, -2)    (-2, 3, -2, 4, -2)  Super flumina babylonis
# 604       (-2, 3, -2, 4, -2)    (-2, 3, -2, 4, -2)  Super flumina babylonis
# 605       (-2, 4, -2, -3, 2)    (-2, 4, -2, -3, 2)  Super flumina babylonis
# ...
# 372  File must be a crim url to have a valid EMA url   8.000000
# 373  File must be a crim url to have a valid EMA url   7.000000
# 374  File must be a crim url to have a valid EMA url  16.000000
# 375  File must be a crim url to have a valid EMA url  14.000000
# 376  File must be a crim url to have a valid EMA url   8.666667
# 377  File must be a crim url to have a valid EMA url  10.000000
# 378  File must be a crim url to have a valid EMA url  16.000000
# 379  File must be a crim url to have a valid EMA url  10.000000
# 380  File must be a crim url to have a valid EMA url   8.000000
# 381  File must be a crim url to have a valid EMA url  17.000000
# 382  File must be a crim url to have a valid EMA url  12.000000
# 383  File must be a crim url to have a valid EMA url  11.000000
# 384  File must be a crim url to have a valid EMA url  11.000000
# 385  File must be a crim url to have a valid EMA url  17.000000
# 386  File must be a crim url to have a valid EMA url   8.000000
# 387  File must be a crim url to have a valid EMA url   9.000000
# 388  File must be a crim url to have a valid EMA url  11.000000
# 389  File must be a crim url to have a valid EMA url  10.000000
# 390  File must be a crim url to have a valid EMA url  14.000000
# 391  File must be a crim url to have a valid EMA url   8.000000
# 392  File must be a crim url to have a valid EMA url  15.000000
# 393  File must be a crim url to have a valid EMA url  12.000000
# 394  File must be a crim url to have a valid EMA url  16.000000
# 395  File must be a crim url to have a valid EMA url  16.000000
# 396  File must be a crim url to have a valid EMA url  19.000000
# 397  File must be a crim url to have a valid EMA url  18.000000
# 398  File must be a crim url to have a valid EMA url  16.000000
# 399  File must be a crim url to have a valid EMA url   9.000000
# 400  File must be a crim url to have a valid EMA url  22.000000
# 401  File must be a crim url to have a valid EMA url  15.000000
# 402  File must be a crim url to have a valid EMA url  16.000000
# 403  File must be a crim url to have a valid EMA url  19.000000
# 404  File must be a crim url to have a valid EMA url  20.000000
# 405  File must be a crim url to have a valid EMA url  18.000000
# 406  File must be a crim url to have a valid EMA url  18.000000
# 407  File must be a crim url to have a valid EMA url  18.000000
# 408  File must be a crim url to have a valid EMA url  10.000000
# 409  File must be a crim url to have a valid EMA url  17.000000
# 410  File must be a crim url to have a valid EMA url  18.000000
# 411  File must be a crim url to have a valid EMA url  18.000000
# 412  File must be a crim url to have a valid EMA url  17.000000
# 413  File must be a crim url to have a valid EMA url  14.000000
# 414  File must be a crim url to have a valid EMA url  11.000000
# 415  File must be a crim url to have a valid EMA url  10.000000
# 416  File must be a crim url to have a valid EMA url  14.000000
# 417  File must be a crim url to have a valid EMA url  15.000000
# 418  File must be a crim url to have a valid EMA url  11.000000
# 419  File must be a crim url to have a valid EMA url  15.000000
# 420  File must be a crim url to have a valid EMA url  14.000000
# 421  File must be a crim url to have a valid EMA url  14.000000
# 422  File must be a crim url to have a valid EMA url  12.000000
# 423  File must be a crim url to have a valid EMA url   9.000000
# 424  File must be a crim url to have a valid EMA url  13.000000
# 425  File must be a crim url to have a valid EMA url  14.000000
# 426  File must be a crim url to have a valid EMA url  14.000000
# 427  File must be a crim url to have a valid EMA url  16.000000
# 428  File must be a crim url to have a valid EMA url  16.000000
# 429  File must be a crim url to have a valid EMA url   9.000000
# 430  File must be a crim url to have a valid EMA url  32.000000
# 431  File must be a crim url to have a valid EMA url  28.000000
# 432  File must be a crim url to have a valid EMA url  11.000000
# 433  File must be a crim url to have a valid EMA url  32.000000
# 434  File must be a crim url to have a valid EMA url  22.000000
# 435  File must be a crim url to have a valid EMA url  28.000000
# 436  File must be a crim url to have a valid EMA url  10.000000
# 437  File must be a crim url to have a valid EMA url  13.000000
# 438  File must be a crim url to have a valid EMA url  16.000000
# 439  File must be a crim url to have a valid EMA url  15.000000
# 440  File must be a crim url to have a valid EMA url  11.000000
# 441  File must be a crim url to have a valid EMA url  16.000000
# 442  File must be a crim url to have a valid EMA url  10.000000
# 443  File must be a crim url to have a valid EMA url  10.000000
# 444  File must be a crim url to have a valid EMA url  10.000000
# 445  File must be a crim url to have a valid EMA url  16.000000
# 446  File must be a crim url to have a valid EMA url  14.000000
# 447  File must be a crim url to have a valid EMA url  14.000000
# 448  File must be a crim url to have a valid EMA url  28.000000
# 449  File must be a crim url to have a valid EMA url  12.000000
# 450  File must be a crim url to have a valid EMA url  14.000000
# 451  File must be a crim url to have a valid EMA url  12.000000
# 452  File must be a crim url to have a valid EMA url  11.000000
# 453  File must be a crim url to have a valid EMA url  32.000000
# 454  File must be a crim url to have a valid EMA url  12.000000
# 455  File must be a crim url to have a valid EMA url  28.000000
# 456  File must be a crim url to have a valid EMA url   7.000000
# 457  File must be a crim url to have a valid EMA url  28.000000
# 458  File must be a crim url to have a valid EMA url  12.000000
# 459  File must be a crim url to have a valid EMA url  24.000000
# 460  File must be a crim url to have a valid EMA url  28.000000
# 461  File must be a crim url to have a valid EMA url  29.000000
# 462  File must be a crim url to have a valid EMA url   9.000000
# 463  File must be a crim url to have a valid EMA url  20.000000
# 464  File must be a crim url to have a valid EMA url  15.000000
# 465  File must be a crim url to have a valid EMA url  14.000000
# 466  File must be a crim url to have a valid EMA url  20.000000
# 467  File must be a crim url to have a valid EMA url  16.000000
# 468  File must be a crim url to have a valid EMA url  12.000000
# 469  File must be a crim url to have a valid EMA url   6.000000
# 470  File must be a crim url to have a valid EMA url  24.000000
# 471  File must be a crim url to have a valid EMA url  23.000000
# 472  File must be a crim url to have a valid EMA url  14.000000
# 473  File must be a crim url to have a valid EMA url  20.000000
# 474  File must be a crim url to have a valid EMA url  14.000000
# 475  File must be a crim url to have a valid EMA url   6.000000
# 476  File must be a crim url to have a valid EMA url  26.000000
# 477  File must be a crim url to have a valid EMA url  12.000000
# 478  File must be a crim url to have a valid EMA url  18.000000
# 479  File must be a crim url to have a valid EMA url  13.000000
# 480  File must be a crim url to have a valid EMA url  28.000000
# 481  File must be a crim url to have a valid EMA url  24.000000
# 482  File must be a crim url to have a valid EMA url  16.000000
# 483  File must be a crim url to have a valid EMA url   9.000000
# 484  File must be a crim url to have a valid EMA url  20.000000
# 485  File must be a crim url to have a valid EMA url  13.000000
# 486  File must be a crim url to have a valid EMA url  22.000000
# 487  File must be a crim url to have a valid EMA url   7.000000
# 488  File must be a crim url to have a valid EMA url  10.000000
# 489  File must be a crim url to have a valid EMA url  16.000000
# 490  File must be a crim url to have a valid EMA url  18.000000
# 491  File must be a crim url to have a valid EMA url  15.000000
# 492  File must be a crim url to have a valid EMA url  14.000000
# 493  File must be a crim url to have a valid EMA url  12.000000
# 494  File must be a crim url to have a valid EMA url  22.000000
# 495  File must be a crim url to have a valid EMA url  26.000000
# 496  File must be a crim url to have a valid EMA url  28.000000
# 497  File must be a crim url to have a valid EMA url  20.000000
# 498  File must be a crim url to have a valid EMA url  12.000000
# 499  File must be a crim url to have a valid EMA url  18.000000
# 500  File must be a crim url to have a valid EMA url  19.000000
# 501  File must be a crim url to have a valid EMA url  12.000000
# 502  File must be a crim url to have a valid EMA url  12.000000
# 503  File must be a crim url to have a valid EMA url  12.000000
# 504  File must be a crim url to have a valid EMA url  15.000000
# 505  File must be a crim url to have a valid EMA url  15.000000
# 506  File must be a crim url to have a valid EMA url  16.000000
# 507  File must be a crim url to have a valid EMA url  14.000000
# 508  File must be a crim url to have a valid EMA url  14.000000
# 509  File must be a crim url to have a valid EMA url  16.000000
# 510  File must be a crim url to have a valid EMA url   8.000000
# 511  File must be a crim url to have a valid EMA url   8.000000
# 512  File must be a crim url to have a valid EMA url   9.000000
# 513  File must be a crim url to have a valid EMA url   8.000000
# 514  File must be a crim url to have a valid EMA url   8.000000
# 515  File must be a crim url to have a valid EMA url   8.000000
# 516  File must be a crim url to have a valid EMA url  13.000000
# 517  File must be a crim url to have a valid EMA url  10.000000
# 518  File must be a crim url to have a valid EMA url  12.000000
# 519  File must be a crim url to have a valid EMA url  10.000000
# 520  File must be a crim url to have a valid EMA url  28.000000
# 521  File must be a crim url to have a valid EMA url  11.000000
# 522  File must be a crim url to have a valid EMA url  24.000000
# 523  File must be a crim url to have a valid EMA url  14.000000
# 524  File must be a crim url to have a valid EMA url  18.000000
# 525  File must be a crim url to have a valid EMA url  14.000000
# 526  File must be a crim url to have a valid EMA url  13.000000
# 527  File must be a crim url to have a valid EMA url  19.000000
# 528  File must be a crim url to have a valid EMA url  13.000000
# 529  File must be a crim url to have a valid EMA url  14.000000
# 530  File must be a crim url to have a valid EMA url  20.000000
# 531  File must be a crim url to have a valid EMA url  16.000000
# 532  File must be a crim url to have a valid EMA url  12.000000
# 533  File must be a crim url to have a valid EMA url  28.000000
# 534  File must be a crim url to have a valid EMA url  12.000000
# 535  File must be a crim url to have a valid EMA url  12.000000
# 536  File must be a crim url to have a valid EMA url  12.000000
# 537  File must be a crim url to have a valid EMA url  12.000000
# 538  File must be a crim url to have a valid EMA url   7.000000
# 539  File must be a crim url to have a valid EMA url   7.000000
# 540  File must be a crim url to have a valid EMA url  13.000000
# 541  File must be a crim url to have a valid EMA url   9.000000
# 542  File must be a crim url to have a valid EMA url   6.000000
# 543  File must be a crim url to have a valid EMA url   9.000000
# 544  File must be a crim url to have a valid EMA url   6.000000
# 545  File must be a crim url to have a valid EMA url   6.000000
# 546  File must be a crim url to have a valid EMA url   6.000000
# 547  File must be a crim url to have a valid EMA url   9.000000
# 548  File must be a crim url to have a valid EMA url  12.000000
# 549  File must be a crim url to have a valid EMA url   8.000000
# 550  File must be a crim url to have a valid EMA url   7.000000
# 551  File must be a crim url to have a valid EMA url   8.000000
# 552  File must be a crim url to have a valid EMA url   8.000000
# 553  File must be a crim url to have a valid EMA url  12.000000
# 554  File must be a crim url to have a valid EMA url  12.000000
# 555  File must be a crim url to have a valid EMA url  12.000000
# 556  File must be a crim url to have a valid EMA url  16.000000
# 557  File must be a crim url to have a valid EMA url  14.000000
# 558  File must be a crim url to have a valid EMA url  15.000000
# 559  File must be a crim url to have a valid EMA url  10.000000
# 560  File must be a crim url to have a valid EMA url  14.000000
# 561  File must be a crim url to have a valid EMA url   8.000000
# 562  File must be a crim url to have a valid EMA url  32.000000
# 563  File must be a crim url to have a valid EMA url  16.000000
# 564  File must be a crim url to have a valid EMA url  18.000000
# 565  File must be a crim url to have a valid EMA url  28.000000
# 566  File must be a crim url to have a valid EMA url  18.000000
# 567  File must be a crim url to have a valid EMA url  24.000000
# 568  File must be a crim url to have a valid EMA url  21.500000
# 569  File must be a crim url to have a valid EMA url  16.000000
# 570  File must be a crim url to have a valid EMA url  10.000000
# 571  File must be a crim url to have a valid EMA url  22.000000
# 572  File must be a crim url to have a valid EMA url  16.000000
# 573  File must be a crim url to have a valid EMA url  10.000000
# 574  File must be a crim url to have a valid EMA url  18.000000
# 575  File must be a crim url to have a valid EMA url  16.000000
# 576  File must be a crim url to have a valid EMA url  16.000000
# 577  File must be a crim url to have a valid EMA url  18.000000
# 578  File must be a crim url to have a valid EMA url  17.000000
# 579  File must be a crim url to have a valid EMA url  17.000000
# 580  File must be a crim url to have a valid EMA url  17.000000
# 581  File must be a crim url to have a valid EMA url  18.000000
# 582  File must be a crim url to have a valid EMA url  16.000000
# 583  File must be a crim url to have a valid EMA url  16.000000
# 584  File must be a crim url to have a valid EMA url  26.000000
# 585  File must be a crim url to have a valid EMA url  16.000000
# 586  File must be a crim url to have a valid EMA url  17.000000
# 587  File must be a crim url to have a valid EMA url  12.000000
# 588  File must be a crim url to have a valid EMA url   9.000000
# 589  File must be a crim url to have a valid EMA url  12.000000
# 590  File must be a crim url to have a valid EMA url   9.500000
# 591  File must be a crim url to have a valid EMA url  23.000000
# 592  File must be a crim url to have a valid EMA url  32.000000
# 593  File must be a crim url to have a valid EMA url  28.000000
# 594  File must be a crim url to have a valid EMA url  10.000000
# 595  File must be a crim url to have a valid EMA url   9.000000
# 596  File must be a crim url to have a valid EMA url  31.000000
# 597  File must be a crim url to have a valid EMA url   8.000000
# 598  File must be a crim url to have a valid EMA url  16.000000
# 599  File must be a crim url to have a valid EMA url  10.000000
# 600  File must be a crim url to have a valid EMA url  12.000000
# 601  File must be a crim url to have a valid EMA url  12.000000
# 602  File must be a crim url to have a valid EMA url   8.000000
# 603  File must be a crim url to have a valid EMA url   8.000000
# 604  File must be a crim url to have a valid EMA url  12.000000
# 605  File must be a crim url to have a valid EMA url  10.000000
# 606  File must be a crim url to have a valid EMA url  12.000000
# 607  File must be a crim url to have a valid EMA url  20.000000
# 608  File must be a crim url to have a valid EMA url  16.000000
# 609  File must be a crim url to have a valid EMA url  20.000000
# 610  File must be a crim url to have a valid EMA url  16.000000
# 611  File must be a crim url to have a valid EMA url  13.000000
# 612  File must be a crim url to have a valid EMA url  11.000000
# 613  File must be a crim url to have a valid EMA url  12.000000

# %%
# now process the original match data df by:
# sorting by start offset, then group by pattern generating match and applying the function above for prev entry
# also give each group a number
# sort by group number and start offset
# so that we can find PARALLEL (=0) Forward Gaps (the distance to NEXT entry), and Backward Gaps (distance to PREVIOUS Entry)
# All Proximate Matches are part of same sub Group (and go to classifier)
# Parallels are part of Sub Group but NOT part of Classified.  We will filter them OUT before classification
# Forward ONLY means the NEXT entry is a GAP.  No problem for Forward ONLY, since these are part of the previous set.
# Backward ONLY means the LAST entry was a GAP.  So these are NEW subgroups, since a new Presentation Type begins
# Forward AND Backward Gaps are SINGLETONS:  We will filter then OUT before Classification
# If an entry is the LAST in a Group and also has a BACKWARD gap it is also a SINGLETON

df2 = df

# Make Groups, Sort By Group and Offset, then and Add Previous/Next
df2["group_number"] = df2.groupby('pattern_matched').ngroup()
df2 = df2.sort_values(['group_number', 'start_offset'])
df2["prev_entry_off"] = df2["start_offset"].shift(1)
df2["next_entry_off"] = df2["start_offset"].shift(-1)


first_of_group = df2.drop_duplicates(subset=["pattern_matched"], keep='first').index
df2["is_first"] = df2.index.isin(first_of_group)
last_of_group = df2.drop_duplicates(subset=["pattern_matched"], keep='last').index
df2["is_last"] = df2.index.isin(last_of_group)

# Check Differences between Next and Last Offset

df2["last_off_diff"] = df2["start_offset"] - df2["prev_entry_off"]
df2["next_off_diff"] = df2["next_entry_off"] - df2["start_offset"]

# Find Parallel Entries 
df2["parallel"] = df2["last_off_diff"] == 0

# Set Gap Limits and Check Gaps Forward and Back
df2["forward_gapped"] = df2["next_off_diff"] >= 50
df2["back_gapped"] = df2["last_off_diff"] >= 50

# Find Singletons and Split Groups with Gaps
df2["singleton"] = ((df2['forward_gapped'] == True) & (df2['back_gapped'] == True) | (df2['back_gapped'] == True) & (df2["is_last"]))
df2["split_group"] = (df2['forward_gapped'] == False) & (df2['back_gapped'] == True)

#Mask Out Parallels and Singletons
df2 = df2[df2["parallel"] != True]
df2 = df2[df2["singleton"] != True]
df2["next_off_diff"] = df2["next_off_diff"].abs()
df2["last_off_diff"] = df2["last_off_diff"].abs()

# Find Final Groups
df2["combined_group"] = (df2.split_group | df2.is_first)
df2.loc[(df2["combined_group"]), "sub_group_id"] = range(df2.combined_group.sum())
df2["sub_group_id"] = df2["sub_group_id"].ffill()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-268-430a006f7440> in <module>
#      14
#      15 # Make Groups, Sort By Group and Offset, then and Add Previous/Next
# ---> 16 df2["group_number"] = df2.groupby('pattern_matched').ngroup()
#      17 df2 = df2.sort_values(['group_number', 'start_offset'])
#      18 df2["prev_entry_off"] = df2["start_offset"].shift(1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in ngroup(self, ascending)
#    2194         with _group_selection_context(self):
#    2195             index = self._selected_obj.index
# -> 2196             result = self._obj_1d_constructor(self.grouper.group_info[0], index)
#    2197             if not ascending:
#    2198                 result = self.ngroups - 1 - result
#
# pandas/_libs/properties.pyx in pandas._libs.properties.CachedProperty.__get__()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in group_info(self)
#     269     @cache_readonly
#     270     def group_info(self):
# --> 271         comp_ids, obs_group_ids = self._get_compressed_codes()
#     272
#     273         ngroups = len(obs_group_ids)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in _get_compressed_codes(self)
#     285
#     286     def _get_compressed_codes(self) -> Tuple[np.ndarray, np.ndarray]:
# --> 287         all_codes = self.codes
#     288         if len(all_codes) > 1:
#     289             group_index = get_group_index(all_codes, self.shape, sort=True, xnull=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in codes(self)
#     230     @property
#     231     def codes(self) -> List[np.ndarray]:
# --> 232         return [ping.codes for ping in self.groupings]
#     233
#     234     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/ops.py in <listcomp>(.0)
#     230     @property
#     231     def codes(self) -> List[np.ndarray]:
# --> 232         return [ping.codes for ping in self.groupings]
#     233
#     234     @property
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in codes(self)
#     563     def codes(self) -> np.ndarray:
#     564         if self._codes is None:
# --> 565             self._make_codes()
#     566         return self._codes
#     567
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in _make_codes(self)
#     591                 else:
#     592                     na_sentinel = -1
# --> 593                 codes, uniques = algorithms.factorize(
#     594                     self.grouper, sort=self.sort, na_sentinel=na_sentinel
#     595                 )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in factorize(values, sort, na_sentinel, size_hint)
#     675             na_value = None
#     676
# --> 677         codes, uniques = _factorize_array(
#     678             values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     679         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/algorithms.py in _factorize_array(values, na_sentinel, size_hint, na_value, mask)
#     498
#     499     table = hash_klass(size_hint or len(values))
# --> 500     uniques, codes = table.factorize(
#     501         values, na_sentinel=na_sentinel, na_value=na_value, mask=mask
#     502     )
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.factorize()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable._unique()
#
# TypeError: unhashable type: 'list'

# %%
df2.sum_durs.hist(bins = 20)
# Out:
# <AxesSubplot:>

# %%
# mask out short soggetti

df2 = df2[df2["sum_durs"] >= 15]

# %%
# run the classifier on the newly curated list of groups

classified2 = df2.applymap(lists_to_tuples_a).groupby("sub_group_id").apply(predict_type_a)

# drop the new singletons

# classified2.drop(classified2[classified2['predicted_type'] == "Singleton"].index, inplace = True)

# classified2 = classified2[classified2["predicted_type"] == "Fuga"]

classified2["start"] = classified2["start_measure"].astype(str) +"/"+ classified2["start_beat"].astype(str) 
classified2.drop(columns=['start_measure', 'start_beat','offset_diffs'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-192-0d2e465f6d04> in <module>
#       1 # run the classifier on the newly curated list of groups
#       2
# ----> 3 classified2 = df2.applymap(lists_to_tuples_a).groupby("sub_group_id").apply(predict_type_a)
#       4
#       5 # drop the new singletons
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    6509         axis = self._get_axis_number(axis)
#    6510
# -> 6511         return DataFrameGroupBy(
#    6512             obj=self,
#    6513             keys=by,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     523             from pandas.core.groupby.grouper import get_grouper
#     524
# --> 525             grouper, exclusions, obj = get_grouper(
#     526                 obj,
#     527                 keys,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/groupby/grouper.py in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     779                 in_axis, name, level, gpr = False, None, gpr, None
#     780             else:
# --> 781                 raise KeyError(gpr)
#     782         elif isinstance(gpr, Grouper) and gpr.key is not None:
#     783             # Add key to exclusions
#
# KeyError: 'sub_group_id'

# %%
# put things back in order by offset and group them again

classified2.sort_values(by = ["start_offset"], inplace=True)
c3 = classified2.groupby(by = ["sub_group_id"])
c3 = c3.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-191-45dcfb2dad2c> in <module>
#       1 # put things back in order by offset and group them again
#       2
# ----> 3 classified2.sort_values(by = ["start_offset"], inplace=True)
#       4 c3 = classified2.groupby(by = ["sub_group_id"])
#       5 c3 = c3.head()
#
# NameError: name 'classified2' is not defined

# %%
# Now transform as Pivot Table
pivot_c3 = c3.pivot_table(index=["piece_title", "pattern_matched", "predicted_type", "sub_group_id"],
            columns="entry_number",
            values=["part", "start_offset", "start"],
            aggfunc=lambda x: x)
pivot_c3_sort = pivot_c3.sort_values(by = [("start_offset", 1)])
pivot_c3_sort = pivot_c3_sort.fillna("-")
pivot_c3_sort.head()

# %%
pivot_c3_sort.reset_index(inplace=True)
pivot_c3_sort = pivot_c3_sort.drop(columns=['start_offset', "sub_group_id"])
pivot_c3_sort.head(50)
# pivot_c3.shape

# %% [markdown]
# # Durational Ratios
#
# #### This Function Calculates the Ratios of the Durations in each Match

# %%
# makes pairs of ratio strings

def pairwise(iterable):
    "s -> (s0,s1), (s1,s2), (s2, s3), ..."
    a, b = tee(iterable)
    next(b, None)
    return zip(a, b)

def get_ratios(input_list):
    ratio_pairs = []
    for a, b in pairwise(input_list):
        ratio_pairs.append(b / a)
    return ratio_pairs

# %% [markdown]
# #### Now call the function to operate on the RESULTS file from earlier

# %%
# calculates 'duration ratios' for each soggetto, then adds this to the DF

results["duration_ratios"] = results.note_durations.apply(get_ratios)
short_results = results.drop(columns=["ema_url", "ema"])
short_results.head()
# Out:
#   pattern_generating_match   pattern_matched piece_title        part  \
# 0         (4, 1, 2, 2, -3)  [4, 1, 2, 2, -3]   Ave Maria  [Superius]
# 1         (4, 1, 2, 2, -3)  [4, 1, 2, 2, -3]   Ave Maria  [Superius]
# 2         (4, 1, 2, 2, -3)  [4, 1, 2, 2, -3]   Ave Maria       Altus
# 3         (4, 1, 2, 2, -3)  [4, 1, 2, 2, -3]   Ave Maria       Tenor
# 4         (4, 1, 2, 2, -3)  [4, 1, 2, 2, -3]   Ave Maria      Bassus
#
#    start_measure  start_beat  end_measure  end_beat  start_offset  end_offset  \
# 0              1         1.0            4       1.0           0.0        24.0
# 1            105         3.0          107       3.5         884.0       910.0
# 2              3         1.0            6       1.0          16.0        40.0
# 3              5         1.0            8       1.0          32.0        56.0
# 4              7         1.0           10       1.0          48.0        72.0
#
#                    note_durations                           duration_ratios
# 0  [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]                 [2.0, 0.5, 1.0, 1.0, 2.0]
# 1  [4.0, 8.0, 4.0, 4.0, 6.0, 2.0]  [2.0, 0.5, 1.0, 1.5, 0.3333333333333333]
# 2  [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]                 [2.0, 0.5, 1.0, 1.0, 2.0]
# 3  [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]                 [2.0, 0.5, 1.0, 1.0, 2.0]
# 4  [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]                 [2.0, 0.5, 1.0, 1.0, 2.0]

# %%
df_s = df[["piece_title", "pattern_generating_match", "part", "start_measure", "start_offset", "predicted_type"]]
df_s.head(20)
# Out:
#    piece_title pattern_generating_match        part  start_measure  \
# 0    Ave Maria         (4, 1, 2, 2, -3)  [Superius]              1
# 1    Ave Maria         (4, 1, 2, 2, -3)  [Superius]            105
# 2    Ave Maria         (4, 1, 2, 2, -3)       Altus              3
# 3    Ave Maria         (4, 1, 2, 2, -3)       Tenor              5
# 4    Ave Maria         (4, 1, 2, 2, -3)      Bassus              7
# 5    Ave Maria      (-2, -2, -2, 2, -2)  [Superius]              8
# 6    Ave Maria      (-2, -2, -2, 2, -2)       Altus             10
# 7    Ave Maria      (-2, -2, -2, 2, -2)       Altus            132
# 8    Ave Maria      (-2, -2, -2, 2, -2)       Tenor             12
# 9    Ave Maria      (-2, -2, -2, 2, -2)      Bassus             91
# 10   Ave Maria      (-2, -2, -2, 2, -2)      Bassus            139
# 11   Ave Maria       (-2, -2, 2, -2, 4)  [Superius]              8
# 12   Ave Maria       (-2, -2, 2, -2, 4)       Altus             10
# 13   Ave Maria       (-2, -2, 2, -2, 4)       Tenor             12
# 14   Ave Maria       (-2, 2, -2, 4, -2)  [Superius]              9
# 15   Ave Maria       (-2, 2, -2, 4, -2)       Altus             11
# 16   Ave Maria       (-2, 2, -2, 4, -2)       Tenor             13
# 17   Ave Maria       (2, -2, 4, -2, -2)  [Superius]              9
# 18   Ave Maria       (2, -2, 4, -2, -2)       Altus             11
# 19   Ave Maria       (2, -2, 4, -2, -2)       Tenor             13
#
#     start_offset                  predicted_type
# 0            0.0  Fuga [16.0, 16.0, 16.0, 836.0]
# 1          884.0  Fuga [16.0, 16.0, 16.0, 836.0]
# 2           16.0  Fuga [16.0, 16.0, 16.0, 836.0]
# 3           32.0  Fuga [16.0, 16.0, 16.0, 836.0]
# 4           48.0  Fuga [16.0, 16.0, 16.0, 836.0]
# 5           56.0        Fuga [16.0, 16.0, 634.0]
# 6           72.0        Fuga [16.0, 16.0, 634.0]
# 7         1109.0        Fuga [16.0, 16.0, 634.0]
# 8           88.0        Fuga [16.0, 16.0, 634.0]
# 9          722.0        Fuga [16.0, 16.0, 634.0]
# 10        1174.0        Fuga [16.0, 16.0, 634.0]
# 11          62.0                PEN [16.0, 16.0]
# 12          78.0                PEN [16.0, 16.0]
# 13          94.0                PEN [16.0, 16.0]
# 14          64.0                PEN [16.0, 16.0]
# 15          80.0                PEN [16.0, 16.0]
# 16          96.0                PEN [16.0, 16.0]
# 17          68.0                PEN [16.0, 16.0]
# 18          84.0                PEN [16.0, 16.0]
# 19         100.0                PEN [16.0, 16.0]

# %% [markdown]
# ## Group by the Pattern Generating Match
# - Each has its own string of durations, and duration ratios
# - and then we compare the ratios to get the differences
# - the "list(combinations)" method takes care of building the pairs, using data from our dataframe 'results'

# %%
def compare_ratios(ratios_1, ratios_2):
    
    ## division of lists 
    # using zip() + list comprehension 
    diffs = [i - j for i, j in zip(ratios_1, ratios_2)] 
    abs_diffs = [abs(ele) for ele in diffs] 
    sum_diffs = sum(abs_diffs)

    return sum_diffs

#results["Pattern_Generating_Match"] = results["Pattern_Generating_Match"].apply(tuple) 

def get_ratio_distances(results, pattern_col, output_cols):
    
    matches = []

    for name, group in results.groupby(pattern_col):

        ratio_pairs = list(combinations(group.index.values, 2))

        for a, b in ratio_pairs:
            
            a_match = results.loc[a]
            b_match = results.loc[b]
            
            sum_diffs = compare_ratios(a_match.duration_ratios, b_match.duration_ratios)
            
            match_dict = {
                "pattern": name,
                "sum_diffs": sum_diffs
            }
            
            for col in output_cols:
                match_dict.update({
                    f"match_1_{col}": a_match[col],
                    f"match_2_{col}": b_match[col]
                })
                
            matches.append(match_dict)
            
    return pd.DataFrame(matches)

# %% [markdown]
# ### Now Run the Function to get the 'edit distances' for the durations of matching patterns

# %%
ratio_distances = get_ratio_distances(results, "pattern_generating_match", ["piece_title", "part", "start_measure", "start_offset"])
ratio_distances
# Out:
#                    pattern  sum_diffs match_1_piece_title match_2_piece_title  \
# 0        (-5, 1, 2, 1, -5)   0.000000           Ave Maria           Ave Maria
# 1     (-3, -2, -2, -2, -2)   5.583333           Ave Maria           Ave Maria
# 2     (-3, -2, -2, -2, -2)   7.583333           Ave Maria           Ave Maria
# 3     (-3, -2, -2, -2, -2)   5.416667           Ave Maria           Ave Maria
# 4     (-3, -2, -2, -2, -2)   3.750000           Ave Maria           Ave Maria
# ...                    ...        ...                 ...                 ...
# 4082   (6, -2, -2, -2, -2)   5.416667           Ave Maria           Ave Maria
# 4083   (6, -2, -2, -2, -2)   6.583333           Ave Maria           Ave Maria
# 4084   (6, -2, -2, -2, -2)   6.416667           Ave Maria           Ave Maria
# 4085   (6, -2, -2, -2, -2)   0.833333           Ave Maria           Ave Maria
# 4086   (8, -2, -2, -2, -2)   3.416667           Ave Maria           Ave Maria
#
#      match_1_part match_2_part  match_1_start_measure  match_2_start_measure  \
# 0          Bassus       Bassus                     94                     98
# 1      [Superius]   [Superius]                     18                     19
# 2      [Superius]   [Superius]                     18                     20
# 3      [Superius]   [Superius]                     18                     85
# 4      [Superius]        Altus                     18                    131
# ...           ...          ...                    ...                    ...
# 4082   [Superius]       Bassus                     20                     90
# 4083        Altus       Bassus                     27                     88
# 4084        Altus       Bassus                     27                     90
# 4085       Bassus       Bassus                     88                     90
# 4086        Tenor        Tenor                     27                     75
#
#       match_1_start_offset  match_2_start_offset
# 0                    756.0                 804.0
# 1                    140.0                 144.0
# 2                    140.0                 158.0
# 3                    140.0                 672.0
# 4                    140.0                1104.0
# ...                    ...                   ...
# 4082                 156.0                 716.0
# 4083                 211.0                 700.0
# 4084                 211.0                 716.0
# 4085                 700.0                 716.0
# 4086                 212.0                 594.0
#
# [4087 rows x 10 columns]

# %% [markdown]
# ### And FILTER the results according to any threshold we like

# %%
ratios_filtered = ratio_distances[ratio_distances.sum_diffs <= 1]
ratios_filtered
# Out:
#                   pattern  sum_diffs match_1_piece_title match_2_piece_title  \
# 0       (-5, 1, 2, 1, -5)   0.000000           Ave Maria           Ave Maria
# 16    (-3, -2, -2, 1, -2)   0.000000           Ave Maria           Ave Maria
# 17     (-3, -2, -2, 1, 1)   0.000000           Ave Maria           Ave Maria
# 31      (-3, 1, 2, -3, 1)   0.000000           Ave Maria           Ave Maria
# 34      (-3, 1, 2, -3, 2)   0.000000           Ave Maria           Ave Maria
# ...                   ...        ...                 ...                 ...
# 4067  (5, -2, -2, -2, -2)   0.833333           Ave Maria           Ave Maria
# 4069    (5, -2, -2, 2, 2)   0.000000           Ave Maria           Ave Maria
# 4077    (5, -2, -2, 2, 2)   0.000000           Ave Maria           Ave Maria
# 4079     (5, 1, 2, -2, 1)   0.000000           Ave Maria           Ave Maria
# 4085  (6, -2, -2, -2, -2)   0.833333           Ave Maria           Ave Maria
#
#      match_1_part match_2_part  match_1_start_measure  match_2_start_measure  \
# 0          Bassus       Bassus                     94                     98
# 16          Altus       Bassus                     57                     62
# 17     [Superius]        Tenor                     56                     61
# 31     [Superius]        Altus                     73                     70
# 34     [Superius]        Altus                     73                     70
# ...           ...          ...                    ...                    ...
# 4067       Bassus       Bassus                     88                     90
# 4069   [Superius]        Tenor                     10                     14
# 4077       Bassus       Bassus                    116                    124
# 4079        Altus       Bassus                     78                     81
# 4085       Bassus       Bassus                     88                     90
#
#       match_1_start_offset  match_2_start_offset
# 0                    756.0                 804.0
# 16                   448.0                 488.0
# 17                   444.0                 484.0
# 31                   582.0                 558.0
# 34                   582.0                 558.0
# ...                    ...                   ...
# 4067                 700.0                 716.0
# 4069                  74.0                 106.0
# 4077                 988.0                1052.0
# 4079                 622.0                 646.0
# 4085                 700.0                 716.0
#
# [856 rows x 10 columns]

# %% [markdown]
# ### Now Group the Duration-Filter Results by the Pattern (which shows us very closely related soggetti in sets)

# %%
grouped = ratios_filtered.groupby("pattern")
len(grouped['pattern'].nunique())
# Out:
# 152

# %%
ratios_filtered.to_csv("filtered_sample_pair.csv")

# %% [markdown]
# ### Greedy Soggetti
# * Groups by voice part
# * Gets one voice, then creates shifted cols to contain current+previous intervals and durations
# * slices each tuple: removes first from previous match and last from current match
# * if these are identical, then we can merge the two soggetti

# %%
results["pattern_matched"] = results["pattern_matched"].apply(tuple)
# results_s = results.drop(columns=["ema_url", "ema", "duration_ratios", "pattern_generating_match"])
# # #results_s["group_number"] = group_number
# # results_grouped = results_s.groupby(by=["piece_title", "part"])
# # results_grouped.sort_values("start_measure")
# # results_grouped.head()
# results_shifted = results_s.groupby(["part"]).shift(1)
# results_shifted.head()

# %%
# function to group by piece and part, then add shfted columns to accept Greedy Data
# the 'df: pd.DataFrame' here is a way of specifying the type that ought to go here
# it's a form of annotation or 'typing'

def add_shifted_cols(df: pd.DataFrame,
                    group_cols: list,
                    shift_cols: list,
                    shift_periods=-1,
                    shifted_prefix="next"
                    ) -> pd.DataFrame:
    
    
    df = df.copy()

    df_shifted = df.groupby(group_cols).shift(shift_periods)

    df[[ f"{shifted_prefix}_{c}" for c in shift_cols]] = df_shifted[shift_cols]

    return df

# %%
# Sequence here helps us deal with tuples in the data, slicing as needed the various lists of vectors and durations

from typing import Sequence

def add_subsequence_cols(df: pd.DataFrame, this_sequence_cols: Sequence, next_sequence_cols: Sequence) -> pd.DataFrame:

    df = df.copy()

    for col in this_sequence_cols:
            df[f"{col}_short"] = df[col].dropna().apply(lambda x: x[1:]) 
    
    for col in next_sequence_cols:
            df[f"{col}_short"] = df[col].dropna().apply(lambda x: x[:-1])
          

    return df

# %%
# here we call the function to add the cols

df_shifted = add_shifted_cols(results,
                    group_cols=["piece_title", "part"],
                    shift_cols=["start_measure", "end_measure", "note_durations", "pattern_matched"])

df_brief = df_shifted.sort_values("start_measure").drop(columns=["ema", "ema_url", "pattern_generating_match"])
df_brief
# Out:
#           pattern_matched piece_title        part  start_measure  start_beat  \
# 0        (4, 1, 2, 2, -3)   Ave Maria  [Superius]              1         1.0
# 2        (4, 1, 2, 2, -3)   Ave Maria       Altus              3         1.0
# 3        (4, 1, 2, 2, -3)   Ave Maria       Tenor              5         1.0
# 4        (4, 1, 2, 2, -3)   Ave Maria      Bassus              7         1.0
# 1032  (-2, -2, -2, 2, -2)   Ave Maria  [Superius]              8         1.0
# ...                   ...         ...         ...            ...         ...
# 617    (-2, -2, -2, 2, 1)   Ave Maria  [Superius]            148         3.0
# 817     (-2, 2, 2, -2, 1)   Ave Maria       Tenor            148         1.0
# 321    (-2, -2, -2, 2, 1)   Ave Maria  [Superius]            148         3.0
# 1070    (-2, 2, 2, -2, 1)   Ave Maria       Tenor            148         1.0
# 1002    (-2, 2, 2, -2, 1)   Ave Maria       Tenor            148         1.0
#
#       end_measure  end_beat  start_offset  end_offset  \
# 0               4       1.0           0.0        24.0
# 2               6       1.0          16.0        40.0
# 3               8       1.0          32.0        56.0
# 4              10       1.0          48.0        72.0
# 1032           10       2.0          56.0        74.0
# ...           ...       ...           ...         ...
# 617           152       3.0        1236.0      1284.0
# 817           152       5.0        1240.0      1288.0
# 321           152       3.0        1236.0      1284.0
# 1070          152       5.0        1240.0      1288.0
# 1002          152       5.0        1240.0      1288.0
#
#                          note_durations  \
# 0        [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]
# 2        [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]
# 3        [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]
# 4        [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]
# 1032     [6.0, 2.0, 4.0, 4.0, 2.0, 2.0]
# ...                                 ...
# 617   [4.0, 4.0, 8.0, 16.0, 16.0, 16.0]
# 817   [4.0, 4.0, 8.0, 16.0, 16.0, 16.0]
# 321   [4.0, 4.0, 8.0, 16.0, 16.0, 16.0]
# 1070  [4.0, 4.0, 8.0, 16.0, 16.0, 16.0]
# 1002  [4.0, 4.0, 8.0, 16.0, 16.0, 16.0]
#
#                                duration_ratios  next_start_measure  \
# 0                    [2.0, 0.5, 1.0, 1.0, 2.0]               105.0
# 2                    [2.0, 0.5, 1.0, 1.0, 2.0]                10.0
# 3                    [2.0, 0.5, 1.0, 1.0, 2.0]                12.0
# 4                    [2.0, 0.5, 1.0, 1.0, 2.0]                91.0
# 1032  [0.3333333333333333, 2.0, 1.0, 0.5, 1.0]               134.0
# ...                                        ...                 ...
# 617                  [1.0, 2.0, 2.0, 1.0, 1.0]                32.0
# 817                  [1.0, 2.0, 2.0, 1.0, 1.0]                37.0
# 321                  [1.0, 2.0, 2.0, 1.0, 1.0]                51.0
# 1070                 [1.0, 2.0, 2.0, 1.0, 1.0]                44.0
# 1002                 [1.0, 2.0, 2.0, 1.0, 1.0]                51.0
#
#       next_end_measure             next_note_durations next_pattern_matched
# 0                107.0  [4.0, 8.0, 4.0, 4.0, 6.0, 2.0]     (4, 1, 2, 2, -3)
# 2                 12.0  [6.0, 2.0, 4.0, 4.0, 3.0, 1.0]  (-2, -2, -2, 2, -2)
# 3                 14.0  [6.0, 2.0, 4.0, 4.0, 2.0, 2.0]  (-2, -2, -2, 2, -2)
# 4                 92.0  [4.0, 1.0, 1.0, 2.0, 2.0, 4.0]  (-2, -2, -2, 3, -2)
# 1032             137.0  [4.0, 4.0, 6.0, 6.0, 6.0, 6.0]  (-2, -2, 2, -2, -2)
# ...                ...                             ...                  ...
# 617               34.0  [4.0, 4.0, 4.0, 2.0, 3.0, 1.0]     (2, 2, 1, 2, -2)
# 817               39.0  [2.0, 3.0, 1.0, 4.0, 2.0, 8.0]    (2, -2, 1, -2, 2)
# 321               52.0  [1.0, 1.0, 1.0, 2.0, 3.0, 1.0]   (-2, -2, 2, 2, -2)
# 1070              46.0  [2.0, 4.0, 4.0, 4.0, 4.0, 4.0]     (2, 2, 2, -3, 2)
# 1002              52.0  [3.0, 1.0, 2.0, 2.0, 2.0, 4.0]   (-2, 2, -3, 2, -3)
#
# [1096 rows x 15 columns]

# %%
# And here we call the function to slice and enter the data

df_brief = add_subsequence_cols(df_shifted, 
    this_sequence_cols=["pattern_matched", "note_durations"], 
    next_sequence_cols=["next_pattern_matched", "next_note_durations"]
    )
df_brief.drop(columns=["ema", "ema_url", "pattern_generating_match", "duration_ratios"])
# Out:
#         pattern_matched piece_title        part  start_measure  start_beat  \
# 0      (4, 1, 2, 2, -3)   Ave Maria  [Superius]              1         1.0
# 1      (4, 1, 2, 2, -3)   Ave Maria  [Superius]            105         3.0
# 2      (4, 1, 2, 2, -3)   Ave Maria       Altus              3         1.0
# 3      (4, 1, 2, 2, -3)   Ave Maria       Tenor              5         1.0
# 4      (4, 1, 2, 2, -3)   Ave Maria      Bassus              7         1.0
# ...                 ...         ...         ...            ...         ...
# 1091  (2, 2, -3, 1, -2)   Ave Maria  [Superius]            106         3.0
# 1092  (2, 2, -3, 3, -2)   Ave Maria       Tenor             21         3.0
# 1093  (1, 2, -3, 2, -2)   Ave Maria       Tenor             81         3.0
# 1094  (2, 2, -4, 2, -2)   Ave Maria      Bassus            131         3.5
# 1095  (2, 2, -3, 2, -2)   Ave Maria      Bassus            138         4.5
#
#       end_measure  end_beat  start_offset  end_offset  \
# 0               4       1.0           0.0        24.0
# 1             107       3.5         884.0       910.0
# 2               6       1.0          16.0        40.0
# 3               8       1.0          32.0        56.0
# 4              10       1.0          48.0        72.0
# ...           ...       ...           ...         ...
# 1091          108       3.0         896.0       920.0
# 1092           23       3.5         164.0       181.0
# 1093           83       2.0         644.0       658.0
# 1094          133       1.0        1109.0      1120.0
# 1095          140       1.5        1167.0      1177.0
#
#                       note_durations  next_start_measure  next_end_measure  \
# 0     [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]               105.0             107.0
# 1     [4.0, 8.0, 4.0, 4.0, 6.0, 2.0]                 8.0              10.0
# 2     [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]                10.0              12.0
# 3     [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]                12.0              14.0
# 4     [4.0, 8.0, 4.0, 4.0, 4.0, 8.0]                91.0              92.0
# ...                              ...                 ...               ...
# 1091  [4.0, 4.0, 6.0, 2.0, 8.0, 4.0]                 NaN               NaN
# 1092  [4.0, 4.0, 4.0, 2.0, 3.0, 1.0]                81.0              83.0
# 1093  [2.0, 2.0, 4.0, 2.0, 4.0, 2.0]                 NaN               NaN
# 1094  [1.0, 2.0, 2.0, 2.0, 4.0, 8.0]               138.0             140.0
# 1095  [1.0, 2.0, 2.0, 2.0, 3.0, 1.0]                 NaN               NaN
#
#                  next_note_durations next_pattern_matched  \
# 0     [4.0, 8.0, 4.0, 4.0, 6.0, 2.0]     (4, 1, 2, 2, -3)
# 1     [6.0, 2.0, 4.0, 4.0, 2.0, 2.0]  (-2, -2, -2, 2, -2)
# 2     [6.0, 2.0, 4.0, 4.0, 3.0, 1.0]  (-2, -2, -2, 2, -2)
# 3     [6.0, 2.0, 4.0, 4.0, 2.0, 2.0]  (-2, -2, -2, 2, -2)
# 4     [4.0, 1.0, 1.0, 2.0, 2.0, 4.0]  (-2, -2, -2, 3, -2)
# ...                              ...                  ...
# 1091                             NaN                  NaN
# 1092  [2.0, 2.0, 4.0, 2.0, 4.0, 2.0]    (1, 2, -3, 2, -2)
# 1093                             NaN                  NaN
# 1094  [1.0, 2.0, 2.0, 2.0, 3.0, 1.0]    (2, 2, -3, 2, -2)
# 1095                             NaN                  NaN
#
#      pattern_matched_short       note_durations_short  \
# 0            (1, 2, 2, -3)  [8.0, 4.0, 4.0, 4.0, 8.0]
# 1            (1, 2, 2, -3)  [8.0, 4.0, 4.0, 6.0, 2.0]
# 2            (1, 2, 2, -3)  [8.0, 4.0, 4.0, 4.0, 8.0]
# 3            (1, 2, 2, -3)  [8.0, 4.0, 4.0, 4.0, 8.0]
# 4            (1, 2, 2, -3)  [8.0, 4.0, 4.0, 4.0, 8.0]
# ...                    ...                        ...
# 1091        (2, -3, 1, -2)  [4.0, 6.0, 2.0, 8.0, 4.0]
# 1092        (2, -3, 3, -2)  [4.0, 4.0, 2.0, 3.0, 1.0]
# 1093        (2, -3, 2, -2)  [2.0, 4.0, 2.0, 4.0, 2.0]
# 1094        (2, -4, 2, -2)  [2.0, 2.0, 2.0, 4.0, 8.0]
# 1095        (2, -3, 2, -2)  [2.0, 2.0, 2.0, 3.0, 1.0]
#
#      next_pattern_matched_short  next_note_durations_short
# 0                  (4, 1, 2, 2)  [4.0, 8.0, 4.0, 4.0, 6.0]
# 1               (-2, -2, -2, 2)  [6.0, 2.0, 4.0, 4.0, 2.0]
# 2               (-2, -2, -2, 2)  [6.0, 2.0, 4.0, 4.0, 3.0]
# 3               (-2, -2, -2, 2)  [6.0, 2.0, 4.0, 4.0, 2.0]
# 4               (-2, -2, -2, 3)  [4.0, 1.0, 1.0, 2.0, 2.0]
# ...                         ...                        ...
# 1091                        NaN                        NaN
# 1092              (1, 2, -3, 2)  [2.0, 2.0, 4.0, 2.0, 4.0]
# 1093                        NaN                        NaN
# 1094              (2, 2, -3, 2)  [1.0, 2.0, 2.0, 2.0, 3.0]
# 1095                        NaN                        NaN
#
# [1096 rows x 18 columns]

# %%
# Now  filter previous results to make sure the melodic and rhythmic vectors match for each sequence

df_filter_durs = df_brief[df_brief["note_durations_short"] == df_brief["next_note_durations_short"]]
df_filter_patts = df_filter_durs[df_filter_durs["pattern_matched_short"] == df_filter_durs["next_pattern_matched_short"]]
df_filter_patts.count()

# %%
# This is just a way to inspect a single voice

df_filter_one_voice = df_filter_patts[df_filter_patts["part"].str.contains('Contratenor')]
df_filter_one_voice.head()

# %%
# Make sure there are no NaN values 

# Add new column for check of matching end measures +1 (which we do by subtracting 1, then checking for ==)
# combine the results:  these are the soggetti that need to get Greedy

df_filter_patts['next_end_measure'].fillna(0)
df_filter_patts['next_end_measure_minus'] = df_filter_patts['next_end_measure'].apply(lambda x: x-1)
df_test_1 = df_filter_patts[df_filter_patts["end_measure"] == df_filter_patts["next_end_measure"]]
df_test_2 = df_filter_patts[df_filter_patts["end_measure"] == df_filter_patts["next_end_measure_minus"]]
df_test_combined = pd.concat([df_test_1, df_test_2])
df_test_combined
